# %%
import spacy
nlp = spacy.load('en_core_web_lg')

# %%
cd ~/PycharmProjects/nlp-colab/no_more_silence/
# Out:
# /Users/jonrenslo/PycharmProjects/nlp-colab/no_more_silence

# %%
pwd
# Out:
# '/Users/jonrenslo/PycharmProjects/nlp-colab/no_more_silence'

# %% [markdown]
# ## Open and describe corpus

# %%
import pandas as pd
# data = pd.read_csv('data/FullDataset/NoMoreSilence_ProjectData.csv',sep="|")
data=pd.read_csv('local_data/NoMoreSilence_ProjectDataV2.tsv',sep='\t')

# %%
data.shape
# Out:
# (735, 55)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Collection Title', 'Title', 'Local Identifier ', 'Type',
#        'Date ', 'Date Type', 'Publication/Origination Info', 'Creator 1 Name',
#        'Creator 1 NameType', 'Creator 1 Source', 'Creator 2 Name',
#        'Creator 2 NameType', 'Creator 2 Source', 'Creator 3 Name',
#        'Creator 3 NameType', 'Creator 3 Source', 'Creator 4 Name',
#        'Creator 4 NameType', 'Creator 4 Source', 'Format/Physical Description',
#        'Language ', 'Language Code', 'Copyright Status', 'Copyright Statement',
#        'Source', 'Subject (Name) 1 Name', 'Subject (Name) 1 Name Type',
#        'Subject (Name) 1 Source', 'Subject (Name) 2 Name',
#        'Subject (Name) 2 Name Type', 'Subject (Name) 2 Source',
#        'Subject (Name) 3 Name', 'Subject (Name) 3 Name Type',
#        'Subject (Name) 3 Source', 'Subject (Topic) 1 Heading',
#        'Subject (Topic) 1 Heading Type', 'Subject (Topic) 1 Source',
#        'Subject (Topic) 2 Heading', 'Subject (Topic) 2 Heading Type',
#        'Subject (Topic) 2 Source', 'Subject (Topic) 3 Heading',
#        'Subject (Topic) 3 Heading Type', 'Subject (Topic) 3 Source',
#        'Subject (Topic) 4 Heading', 'Subject (Topic) 4 Heading Type',
#        'Subject (Topic) 4 Source', 'Subject (Topic) 5 Heading',
#        'Subject (Topic) 5 Heading Type', 'Subject (Topic) 5 Source',
#        'Subject (Topic) 6 Heading', 'Subject (Topic) 6 Heading Type',
#        'Subject (Topic) 6 Source', 'Ocr text', 'Corrected Text'],
#       dtype='object')

# %%
data['Ocr text'].describe()
# Out:
# count     735
# unique    637
# top
# freq       99
# Name: Ocr text, dtype: object

# %%
print(data['Ocr text'].isna().sum())
print((data["Ocr text"].map(str.isspace)).sum())
# Out:
# 0
# 99

# %%
data.head()
# Out:
#    Unnamed: 0                                   Collection Title  \
# 0           0  AIDS Legal Referral Panel Records, 2000-46, Bo...
# 1           1  AIDS Legal Referral Panel Records, 2000-46, Bo...
# 2           2  AIDS Legal Referral Panel Records, 2000-46, Bo...
# 3           3  AIDS Legal Referral Panel Records, 2000-46, Bo...
# 4           4  AIDS Legal Referral Panel Records, 2000-46, Bo...
#
#                                           Title       Local Identifier   Type  \
# 0  "Prop 64: The AIDS Initiative in California"   glbths_200046_003_002  text
# 1                                    Management   glbths_200046_004_004  text
# 2                                Board Meetings   glbths_200046_009_005  text
# 3                                Correspondence  glbths_200046_001_0010  text
# 4                            Letters of support   glbths_200046_003_006  text
#
#         Date  Date Type                       Publication/Origination Info  \
# 0        1986   created  Digital resource published by the Regents of t...
# 1  circa 1992   created  Digital resource published by the Regents of t...
# 2   1995-1996   created  Digital resource published by the Regents of t...
# 3   1985-1987   created  Digital resource published by the Regents of t...
# 4        1993   created  Digital resource published by the Regents of t...
#
#               Creator 1 Name Creator 1 NameType  \
# 0  AIDS Legal Referral Panel           corpname
# 1  AIDS Legal Referral Panel           corpname
# 2  AIDS Legal Referral Panel           corpname
# 3  AIDS Legal Referral Panel           corpname
# 4  AIDS Legal Referral Panel           corpname
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#   Subject (Topic) 4 Heading Type Subject (Topic) 4 Source  \
# 0                          topic                     lcsh
# 1                          topic                     lcsh
# 2                          topic                     lcsh
# 3                          topic                     lcsh
# 4                          topic                     lcsh
#
#   Subject (Topic) 5 Heading Subject (Topic) 5 Heading Type  \
# 0
# 1
# 2
# 3
# 4
#
#   Subject (Topic) 5 Source Subject (Topic) 6 Heading  \
# 0
# 1
# 2
# 3
# 4
#
#   Subject (Topic) 6 Heading Type Subject (Topic) 6 Source  \
# 0
# 1
# 2
# 3
# 4
#
#                                             Ocr text  \
# 0  PROPOSITION 64 The AIDSInitiativein California...
# 1  MAKING YOUR WILL California State Aids Legal S...
# 2  January 11, 1997 Community Liaison Committee c...
# 3  ^ GREAT REPUBLIC IIMSURAIMCE COMPANY i 470 SOU...
# 4  SANFRANCISCOAIDSFOUNDATION P.O.BOX 426182,SANF...
#
#                                       Corrected Text
# 0   proposition 64 the aids initiative in califor...
# 1   making your will california state aids legal ...
# 2   january 11,1997 community liaison committee c...
# 3   great republic iimsuraimce company i 470 sout...
# 4   san francisco aids foundation p. o. box 42618...
#
# [5 rows x 55 columns]

# %%
data['Collection Title'].value_counts()
# Out:
# AIDS History Project — Ephemera Collection, MSS 2000-31, box 4                         33
# Sally Hughes AIDS research collection, MSS 2001-04, carton 1, SFGH AIDS Ward folder    21
# AIDS Legal Referral Panel Records, 2000-46, Box 4, Folder 1                            17
# AIDS History Project Ephemera Collection, MSS 2000-31                                  15
#                                                                                         9
# Selma Dritz papers, MSS 2009-04, carton 1, folder 12                                    5
# Selma Dritz papers, MSS 2009-04, carton 1, folder 4                                     4
# Selma Dritz papers, MSS 2009-04, carton 1, folder 14                                    4
# People vs. Owen Bathhouse Closure Litigation Records, SFH 31, Box 1, Folder 3           3
# Selma Dritz papers, MSS 2009-04, carton 1, folder 17                                    3
# Selma Dritz papers, MSS 2009-04, carton 1, folder 22                                    3
# Selma Dritz papers, MSS 2009-04, carton 1, folder 15                                    2
# Selma Dritz papers, MSS 2009-04, carton 1, folder 21                                    2
# Mobilization Against AIDS records, , MSS 95-03, carton 2 folder 37                      2
# Barbara Cameron Papers, GLC 63, Box 1, Folder 63                                        2
# AIDS Legal Referral Panel Records, 2000-46, Box 3, Folder 11-12                         2
# People vs. Owen Bathhouse Closure Litigation Records, SFH 31, Box 1, Folder 14-15       2
# People vs. Owen Bathhouse Closure Litigation Records, SFH 31, Box 1, Folder 19-21       2
# Women's AIDS Network (WAN) records, MSS 95-04, Carton 1 Folder 68-69                    2
# Shanti Project records, MSS 98-48, box 1, folder 28                                     2
# Selma Dritz papers, MSS 2009-04, carton 2, folder 16                                    2
# AIDS Legal Referral Panel Records, 2000-46, Box 4, Folder 8                             2
# Mobilization Against AIDS records, , MSS 95-03, carton 3 folder 39                      2
# People vs. Owen Bathhouse Closure Litigation Records, SFH 31, Box 1, Folder 12          1
# AIDS Legal Referral Panel Records, 2000-46, Box 5, Folder 11                            1
# Linda Alband collection of Randy Shilts materials, 2003-09, Carton 2, Folder 23         1
# Mobilization Against AIDS records, , MSS 95-03, carton 2 folder 11                      1
# AIDS Legal Referral Panel Records, 2000-46, Box 3, Folder 5                             1
# Mobilization Against AIDS records, , MSS 95-03, carton 3 folder 18                      1
# Sue Rochman Papers, 2005-13, Box 1, Folder 3                                            1
#                                                                                        ..
# Linda Alband collection of Randy Shilts materials, 2003-09, Carton 2, Folder 143        1
# Linda Alband collection of Randy Shilts materials, 2003-09, Carton 2, Folder 55         1
# Linda Alband collection of Randy Shilts materials, 2003-09, Carton 2, Folder 16         1
# Women's AIDS Network (WAN) records, MSS 95-04, Carton 1 Folder 30                       1
# Linda Alband collection of Randy Shilts materials, 2003-09, Carton 3, Folder 17         1
# Women's AIDS Network (WAN) records, MSS 95-04, Carton 1 Folder 24                       1
# Shanti Project records, MSS 98-48, box 1, folder 26                                     1
# Mobilization Against AIDS records, MSS 95-03, carton 1 folder 5                         1
# Linda Alband collection of Randy Shilts materials, 2003-09, Carton 3, Folder 7          1
# AIDS Legal Referral Panel Records, 2000-46, Box 5, Folder 9                             1
# Linda Alband collection of Randy Shilts materials, 2003-09, Carton 1, Folder 27         1
# Women's AIDS Network (WAN) records, MSS 95-04, Carton 1 Folder 70                       1
# People vs. Owen Bathhouse Closure Litigation Records, SFH 31, Box 1, Folder 17          1
# Linda Alband collection of Randy Shilts materials, 2003-09, Carton 2, Folder 47         1
# Linda Alband collection of Randy Shilts materials, 2003-09, Carton 2, Folder 136        1
# Mobilization Against AIDS records, , MSS 95-03, carton 2 folder 33                      1
# AIDS Legal Referral Panel Records, 2000-46, Box 2, Folder 3                             1
# AIDS Legal Referral Panel Records, 2000-46, Box 3, Folder 2                             1
# Linda Alband collection of Randy Shilts materials, 2003-09, Carton 2, Folder 49         1
# AIDS Legal Referral Panel Records, 2000-46, Box 3, Folder 7                             1
# Mobilization Against AIDS records, , MSS 95-03, carton 2 folder 18                      1
# Linda Alband collection of Randy Shilts materials, 2003-09, Carton 1, Folder 15         1
# Mobilization Against AIDS records, , MSS 95-03, carton 2 folder 57                      1
# Shanti Project records, MSS 98-48, box 1, folder 6                                      1
# Mobilization Against AIDS records, , MSS 95-03, carton 2 folder 6                       1
# Mobilization Against AIDS records, MSS 95-03, carton 1 folder 32                        1
# Mobilization Against AIDS records, MSS 95-03, carton 1 folder 6                         1
# Linda Alband collection of Randy Shilts materials, 2003-09, Carton 2, Folder 36         1
# Linda Alband collection of Randy Shilts materials, 2003-09, Carton 2, Folder 79         1
# Mobilization Against AIDS records, , MSS 95-03, carton 2 folder 42                      1
# Name: Collection Title, Length: 613, dtype: int64

# %%
data[data['Collection Title'].map(lambda a: isinstance(a, float))]  
# confirmed these missing  rows are imported correctly
# Out:
#      Unnamed: 0 Collection Title                                 Title  \
# 344         344              NaN  MSS 2000-31 AIDS Ephemera Collection
# 357         357              NaN                                Public
# 395         395              NaN                     MSS 2009-04 Dritz
# 648         648              NaN  MSS 98-47 ACT-UP Golden Gate records
#
#     Local Identifier  Type Date  Date Type Publication/Origination Info  \
# 344
# 357
# 395
# 648
#
#     Creator 1 Name Creator 1 NameType      ...        \
# 344                                        ...
# 357                                        ...
# 395                                        ...
# 648                                        ...
#
#     Subject (Topic) 4 Heading Type Subject (Topic) 4 Source  \
# 344
# 357
# 395
# 648
#
#     Subject (Topic) 5 Heading Subject (Topic) 5 Heading Type  \
# 344
# 357
# 395
# 648
#
#     Subject (Topic) 5 Source Subject (Topic) 6 Heading  \
# 344
# 357
# 395
# 648
#
#     Subject (Topic) 6 Heading Type Subject (Topic) 6 Source Ocr text  \
# 344
# 357
# 395
# 648
#
#     Corrected Text
# 344
# 357
# 395
# 648
#
# [4 rows x 55 columns]

# %%
data['Ocr text'].map(type).value_counts()
# Out:
# <class 'str'>    735
# Name: Ocr text, dtype: int64

# %%
data['Ocr text'].map(len).describe()
# Out:
# count       735.000000
# mean      70714.420408
# std      110159.634847
# min           1.000000
# 25%        7410.500000
# 50%       27285.000000
# 75%       84169.500000
# max      813212.000000
# Name: Ocr text, dtype: float64

# %% [markdown]
# ## Process Document OCR Data

# %%
# Process docs
import tqdm as tqdm_mod
from tqdm import tqdm, tqdm_notebook, tqdm_pandas
tqdm.pandas()
parsed = data['Corrected Text'].progress_map(nlp)
# Out:
#   0%|          | 0/735 [00:00<?, ?it/s]
#
#
#
#
#
#
#   0%|          | 2/735 [00:05<32:58,  2.70s/it]
#
#
#
#
#
#
#   0%|          | 3/735 [00:05<24:49,  2.03s/it]
#
#
#
#
#
#
#   1%|          | 4/735 [00:27<1:34:40,  7.77s/it]
#
#
#
#
#
#
#   1%|          | 5/735 [00:47<2:20:51, 11.58s/it]
#
#
#
#
#
#
#   1%|          | 6/735 [00:48<1:40:48,  8.30s/it]
#
#
#
#
#
#
#   1%|          | 7/735 [01:16<2:52:29, 14.22s/it]
#
#
#
#
#
#
#   1%|          | 8/735 [01:19<2:14:09, 11.07s/it]
#
#
#
#
#
#
#   1%|          | 9/735 [01:21<1:40:21,  8.29s/it]
#
#
#
#
#
#
#   1%|▏         | 10/735 [01:28<1:34:27,  7.82s/it]
#
#
#
#
#
#
#   1%|▏         | 11/735 [01:31<1:17:34,  6.43s/it]
#
#
#
#
#
#
#   2%|▏         | 12/735 [01:38<1:18:07,  6.48s/it]
#
#
#
#
#
#
#   2%|▏         | 13/735 [01:38<55:10,  4.59s/it]
#
#
#
#
#
#
#   2%|▏         | 14/735 [02:02<2:05:51, 10.47s/it]
#
#
#
#
#
#
#   2%|▏         | 15/735 [02:03<1:30:12,  7.52s/it]
#
#
#
#
#
#
#   2%|▏         | 16/735 [02:04<1:06:15,  5.53s/it]
#
#
#
#
#
#
#   2%|▏         | 17/735 [02:18<1:39:28,  8.31s/it]
#
#
#
#
#
#
#   3%|▎         | 19/735 [02:26<1:23:06,  6.96s/it]
#
#
#
#
#
#
#   3%|▎         | 20/735 [02:28<1:06:41,  5.60s/it]
#
#
#
#
#
#
#   3%|▎         | 21/735 [02:37<1:16:19,  6.41s/it]
#
#
#
#
#
#
#   3%|▎         | 22/735 [02:43<1:16:56,  6.48s/it]
#
#
#
#
#
#
#   3%|▎         | 23/735 [03:09<2:24:51, 12.21s/it]
#
#
#
#
#
#
#   3%|▎         | 24/735 [03:42<3:40:03, 18.57s/it]
#
#
#
#
#
#
#   3%|▎         | 25/735 [03:58<3:28:14, 17.60s/it]
#
#
#
#
#
#
#   4%|▎         | 26/735 [04:10<3:08:54, 15.99s/it]
#
#
#
#
#
#
#   4%|▎         | 27/735 [04:13<2:22:40, 12.09s/it]
#
#
#
#
#
#
#   4%|▍         | 28/735 [04:14<1:42:49,  8.73s/it]
#
#
#
#
#
#
#   4%|▍         | 29/735 [04:37<2:32:17, 12.94s/it]
#
#
#
#
#
#
#   4%|▍         | 30/735 [04:48<2:24:57, 12.34s/it]
#
#
#
#
#
#
#   4%|▍         | 31/735 [04:53<1:59:23, 10.18s/it]
#
#
#
#
#
#
#   4%|▍         | 32/735 [04:53<1:25:36,  7.31s/it]
#
#
#
#
#
#
#   4%|▍         | 33/735 [04:55<1:07:11,  5.74s/it]
#
#
#
#
#
#
#   5%|▍         | 34/735 [05:00<1:01:51,  5.29s/it]
#
#
#
#
#
#
#   5%|▍         | 35/735 [05:00<43:43,  3.75s/it]
#
#
#
#
#
#
#   5%|▍         | 36/735 [05:00<32:35,  2.80s/it]
#
#
#
#
#
#
#   5%|▌         | 37/735 [05:16<1:16:50,  6.61s/it]
#
#
#
#
#
#
#   5%|▌         | 38/735 [05:18<1:02:36,  5.39s/it]
#
#
#
#
#
#
#   5%|▌         | 39/735 [05:21<53:39,  4.63s/it]
#
#
#
#
#
#
#   5%|▌         | 40/735 [32:54<96:21:01, 499.08s/it]
#
#
#
#
#
#
#   6%|▌         | 41/735 [32:58<67:35:36, 350.63s/it]
#
#
#
#
#
#
#   6%|▌         | 42/735 [33:10<47:56:26, 249.04s/it]
#
#
#
#
#
#
#   6%|▌         | 44/735 [33:23<33:49:00, 176.18s/it]
#
#
#
#
#
#
#   6%|▌         | 45/735 [39:42<45:28:42, 237.28s/it]
#
#
#
#
#
#
#   6%|▋         | 46/735 [39:45<31:54:28, 166.72s/it]
#
#
#
#
#
#
#   6%|▋         | 47/735 [40:09<23:42:10, 124.03s/it]
#
#
#
#
#
#
#   7%|▋         | 48/735 [40:10<16:37:24, 87.11s/it]
#
#
#
#
#
#
#   7%|▋         | 49/735 [40:16<11:59:18, 62.91s/it]
#
#
#
#
#
#
#   7%|▋         | 50/735 [40:19<8:32:34, 44.90s/it]
#
#
#
#
#
#
#   7%|▋         | 51/735 [40:22<6:07:33, 32.24s/it]
#
#
#
#
#
#
#   7%|▋         | 52/735 [40:37<5:06:52, 26.96s/it]
#
#
#
#
#
#
#   7%|▋         | 53/735 [40:42<3:54:36, 20.64s/it]
#
#
#
#
#
#
#   7%|▋         | 54/735 [40:51<3:13:11, 17.02s/it]
#
#
#
#
#
#
#   7%|▋         | 55/735 [40:52<2:18:01, 12.18s/it]
#
#
#
#
#
#
#   8%|▊         | 56/735 [41:01<2:07:46, 11.29s/it]
#
#
#
#
#
#
#   8%|▊         | 57/735 [42:01<4:51:58, 25.84s/it]
#
#
#
#
#
#
#   8%|▊         | 58/735 [42:01<3:24:28, 18.12s/it]
#
#
#
#
#
#
#   8%|▊         | 59/735 [42:31<4:04:00, 21.66s/it]
#
#
#
#
#
#
#   8%|▊         | 60/735 [42:32<2:53:32, 15.43s/it]
#
#
#
#
#
#
#   8%|▊         | 61/735 [42:50<3:01:25, 16.15s/it]
#
#
#
#
#
#
#   8%|▊         | 62/735 [42:54<2:22:54, 12.74s/it]
#
#
#
#
#
#
#   9%|▊         | 63/735 [42:55<1:41:32,  9.07s/it]
#
#
#
#
#
#
#   9%|▊         | 64/735 [42:55<1:11:32,  6.40s/it]
#
#
#
#
#
#
#   9%|▉         | 65/735 [43:00<1:04:54,  5.81s/it]
#
#
#
#
#
#
#   9%|▉         | 66/735 [43:20<1:52:52, 10.12s/it]
#
#
#
#
#
#
#   9%|▉         | 67/735 [43:20<1:21:12,  7.29s/it]
#
#
#
#
#
#
#   9%|▉         | 68/735 [43:27<1:18:33,  7.07s/it]
#
#
#
#
#
#
#   9%|▉         | 69/735 [43:34<1:17:48,  7.01s/it]
#
#
#
#
#
#
#  10%|▉         | 70/735 [43:47<1:37:43,  8.82s/it]
#
#
#
#
#
#
#  10%|▉         | 71/735 [43:48<1:12:35,  6.56s/it]
#
#
#
#
#
#
#  10%|▉         | 72/735 [43:49<53:00,  4.80s/it]
#
#
#
#
#
#
#  10%|▉         | 73/735 [43:49<38:07,  3.46s/it]
#
#
#
#
#
#
#  10%|█         | 74/735 [43:50<29:30,  2.68s/it]
#
#
#
#
#
#
#  10%|█         | 75/735 [43:52<25:52,  2.35s/it]
#
#
#
#
#
#
#  10%|█         | 76/735 [43:52<20:15,  1.84s/it]
#
#
#
#
#
#
#  10%|█         | 77/735 [43:54<21:19,  1.94s/it]
#
#
#
#
#
#
#  11%|█         | 78/735 [43:55<15:45,  1.44s/it]
#
#
#
#
#
#
#  11%|█         | 79/735 [43:58<22:47,  2.08s/it]
#
#
#
#
#
#
#  11%|█         | 80/735 [44:00<19:53,  1.82s/it]
#
#
#
#
#
#
#  11%|█         | 81/735 [44:00<14:58,  1.37s/it]
#
#
#
#
#
#
#  11%|█         | 82/735 [44:00<11:21,  1.04s/it]
#
#
#
#
#
#
#  11%|█▏        | 84/735 [44:01<08:34,  1.27it/s]
#
#
#
#
#
#
#  12%|█▏        | 85/735 [44:01<08:26,  1.28it/s]
#
#
#
#
#
#
#  12%|█▏        | 86/735 [44:04<15:55,  1.47s/it]
#
#
#
#
#
#
#  12%|█▏        | 87/735 [44:05<12:43,  1.18s/it]
#
#
#
#
#
#
#  12%|█▏        | 88/735 [44:09<23:30,  2.18s/it]
#
#
#
#
#
#
#  12%|█▏        | 89/735 [44:10<19:14,  1.79s/it]
#
#
#
#
#
#
#  12%|█▏        | 90/735 [44:11<14:29,  1.35s/it]
#
#
#
#
#
#
#  12%|█▏        | 91/735 [44:13<16:41,  1.56s/it]
#
#
#
#
#
#
#  13%|█▎        | 92/735 [44:35<1:22:54,  7.74s/it]
#
#
#
#
#
#
#  13%|█▎        | 93/735 [44:36<1:00:30,  5.65s/it]
#
#
#
#
#
#
#  13%|█▎        | 94/735 [44:36<45:09,  4.23s/it]
#
#
#
#
#
#
#  13%|█▎        | 95/735 [44:38<35:12,  3.30s/it]
#
#
#
#
#
#
#  13%|█▎        | 96/735 [44:38<26:41,  2.51s/it]
#
#
#
#
#
#
#  13%|█▎        | 98/735 [44:41<23:40,  2.23s/it]
#
#
#
#
#
#
#  13%|█▎        | 99/735 [45:01<1:19:33,  7.51s/it]
#
#
#
#
#
#
#  14%|█▎        | 100/735 [45:21<1:57:20, 11.09s/it]
#
#
#
#
#
#
#  14%|█▎        | 101/735 [45:22<1:26:33,  8.19s/it]
#
#
#
#
#
#
#  14%|█▍        | 102/735 [45:25<1:08:50,  6.53s/it]
#
#
#
#
#
#
#  14%|█▍        | 103/735 [45:26<52:16,  4.96s/it]
#
#
#
#
#
#
#  14%|█▍        | 104/735 [45:29<44:41,  4.25s/it]
#
#
#
#
#
#
#  14%|█▍        | 105/735 [45:34<47:57,  4.57s/it]
#
#
#
#
#
#
#  14%|█▍        | 106/735 [45:35<36:48,  3.51s/it]
#
#
#
#
#
#
#  15%|█▍        | 107/735 [45:36<29:37,  2.83s/it]
#
#
#
#
#
#
#  15%|█▍        | 108/735 [45:39<27:44,  2.65s/it]
#
#
#
#
#
#
#  15%|█▍        | 109/735 [45:40<22:53,  2.19s/it]
#
#
#
#
#
#
#  15%|█▍        | 110/735 [45:40<17:25,  1.67s/it]
#
#
#
#
#
#
#  15%|█▌        | 111/735 [45:46<30:04,  2.89s/it]
#
#
#
#
#
#
#  15%|█▌        | 112/735 [45:47<24:04,  2.32s/it]
#
#
#
#
#
#
#  15%|█▌        | 113/735 [45:49<23:17,  2.25s/it]
#
#
#
#
#
#
#  16%|█▌        | 114/735 [45:50<19:47,  1.91s/it]
#
#
#
#
#
#
#  16%|█▌        | 115/735 [46:00<43:51,  4.24s/it]
#
#
#
#
#
#
#  16%|█▌        | 116/735 [46:00<32:22,  3.14s/it]
#
#
#
#
#
#
#  16%|█▌        | 117/735 [46:03<29:50,  2.90s/it]
#
#
#
#
#
#
#  16%|█▌        | 118/735 [46:11<45:58,  4.47s/it]
#
#
#
#
#
#
#  16%|█▌        | 119/735 [46:26<1:20:29,  7.84s/it]
#
#
#
#
#
#
#  16%|█▋        | 120/735 [46:28<1:00:00,  5.85s/it]
#
#
#
#
#
#
#  16%|█▋        | 121/735 [46:29<45:16,  4.42s/it]
#
#
#
#
#
#
#  17%|█▋        | 122/735 [46:30<35:41,  3.49s/it]
#
#
#
#
#
#
#  17%|█▋        | 123/735 [46:35<40:30,  3.97s/it]
#
#
#
#
#
#
#  17%|█▋        | 125/735 [46:36<29:46,  2.93s/it]
#
#
#
#
#
#
#  17%|█▋        | 126/735 [46:38<25:07,  2.48s/it]
#
#
#
#
#
#
#  17%|█▋        | 127/735 [46:39<23:19,  2.30s/it]
#
#
#
#
#
#
#  17%|█▋        | 128/735 [46:40<16:41,  1.65s/it]
#
#
#
#
#
#
#  18%|█▊        | 129/735 [46:40<12:45,  1.26s/it]
#
#
#
#
#
#
#  18%|█▊        | 130/735 [46:42<14:43,  1.46s/it]
#
#
#
#
#
#
#  18%|█▊        | 131/735 [46:43<12:51,  1.28s/it]
#
#
#
#
#
#
#  18%|█▊        | 132/735 [46:53<38:39,  3.85s/it]
#
#
#
#
#
#
#  18%|█▊        | 133/735 [46:55<34:59,  3.49s/it]
#
#
#
#
#
#
#  18%|█▊        | 134/735 [46:56<25:47,  2.57s/it]
#
#
#
#
#
#
#  18%|█▊        | 135/735 [46:57<20:44,  2.07s/it]
#
#
#
#
#
#
#  19%|█▊        | 136/735 [46:58<17:33,  1.76s/it]
#
#
#
#
#
#
#  19%|█▊        | 137/735 [46:59<17:51,  1.79s/it]
#
#
#
#
#
#
#  19%|█▉        | 138/735 [47:00<13:36,  1.37s/it]
#
#
#
#
#
#
#  19%|█▉        | 139/735 [47:02<14:32,  1.46s/it]
#
#
#
#
#
#
#  19%|█▉        | 140/735 [47:03<15:31,  1.57s/it]
#
#
#
#
#
#
#  19%|█▉        | 141/735 [47:04<13:50,  1.40s/it]
#
#
#
#
#
#
#  19%|█▉        | 142/735 [47:05<12:39,  1.28s/it]
#
#
#
#
#
#
#  19%|█▉        | 143/735 [47:06<12:10,  1.23s/it]
#
#
#
#
#
#
#  20%|█▉        | 144/735 [47:11<21:21,  2.17s/it]
#
#
#
#
#
#
#  20%|█▉        | 145/735 [47:13<22:08,  2.25s/it]
#
#
#
#
#
#
#  20%|█▉        | 146/735 [47:15<20:45,  2.11s/it]
#
#
#
#
#
#
#  20%|██        | 147/735 [47:19<25:33,  2.61s/it]
#
#
#
#
#
#
#  20%|██        | 148/735 [47:19<18:53,  1.93s/it]
#
#
#
#
#
#
#  20%|██        | 149/735 [47:20<15:34,  1.59s/it]
#
#
#
#
#
#
#  20%|██        | 150/735 [47:22<15:19,  1.57s/it]
#
#
#
#
#
#
#  21%|██        | 151/735 [47:22<13:22,  1.37s/it]
#
#
#
#
#
#
#  21%|██        | 152/735 [47:28<25:45,  2.65s/it]
#
#
#
#
#
#
#  21%|██        | 153/735 [47:30<24:13,  2.50s/it]
#
#
#
#
#
#
#  21%|██        | 154/735 [47:31<18:42,  1.93s/it]
#
#
#
#
#
#
#  21%|██        | 155/735 [53:07<16:28:09, 102.22s/it]
#
#
#
#
#
#
#  21%|██        | 156/735 [53:08<11:34:40, 71.99s/it]
#
#
#
#
#
#
#  21%|██▏       | 157/735 [53:10<8:08:50, 50.75s/it]
#
#
#
#
#
#
#  21%|██▏       | 158/735 [53:10<5:43:56, 35.77s/it]
#
#
#
#
#
#
#  22%|██▏       | 159/735 [53:11<4:01:19, 25.14s/it]
#
#
#
#
#
#
#  22%|██▏       | 160/735 [53:12<2:51:21, 17.88s/it]
#
#
#
#
#
#
#  22%|██▏       | 161/735 [53:12<2:01:29, 12.70s/it]
#
#
#
#
#
#
#  22%|██▏       | 162/735 [53:29<2:13:18, 13.96s/it]
#
#
#
#
#
#
#  22%|██▏       | 163/735 [53:30<1:35:10,  9.98s/it]
#
#
#
#
#
#
#  22%|██▏       | 164/735 [53:32<1:12:52,  7.66s/it]
#
#
#
#
#
#
#  22%|██▏       | 165/735 [53:34<56:00,  5.90s/it]
#
#
#
#
#
#
#  23%|██▎       | 166/735 [53:47<1:17:26,  8.17s/it]
#
#
#
#
#
#
#  23%|██▎       | 167/735 [53:48<56:02,  5.92s/it]
#
#
#
#
#
#
#  23%|██▎       | 168/735 [53:49<40:57,  4.34s/it]
#
#
#
#
#
#
#  23%|██▎       | 169/735 [53:51<36:11,  3.84s/it]
#
#
#
#
#
#
#  23%|██▎       | 170/735 [53:52<25:42,  2.73s/it]
#
#
#
#
#
#
#  23%|██▎       | 171/735 [53:54<24:49,  2.64s/it]
#
#
#
#
#
#
#  23%|██▎       | 172/735 [53:54<17:52,  1.90s/it]
#
#
#
#
#
#
#  24%|██▎       | 173/735 [53:57<19:16,  2.06s/it]
#
#
#
#
#
#
#  24%|██▎       | 174/735 [54:00<23:20,  2.50s/it]
#
#
#
#
#
#
#  24%|██▍       | 175/735 [54:00<16:58,  1.82s/it]
#
#
#
#
#
#
#  24%|██▍       | 176/735 [54:01<13:37,  1.46s/it]
#
#
#
#
#
#
#  24%|██▍       | 177/735 [54:05<21:50,  2.35s/it]
#
#
#
#
#
#
#  24%|██▍       | 178/735 [58:02<11:13:08, 72.51s/it]
#
#
#
#
#
#
#  24%|██▍       | 179/735 [58:03<7:54:30, 51.21s/it]
#
#
#
#
#
#
#  24%|██▍       | 180/735 [58:05<5:37:09, 36.45s/it]
#
#
#
#
#
#
#  25%|██▍       | 181/735 [58:13<4:17:16, 27.86s/it]
#
#
#
#
#
#
#  25%|██▍       | 182/735 [58:15<3:04:03, 19.97s/it]
#
#
#
#
#
#
#  25%|██▍       | 183/735 [58:16<2:12:41, 14.42s/it]
#
#
#
#
#
#
#  25%|██▌       | 184/735 [58:25<1:58:05, 12.86s/it]
#
#
#
#
#
#
#  25%|██▌       | 185/735 [58:26<1:24:29,  9.22s/it]
#
#
#
#
#
#
#  25%|██▌       | 186/735 [58:30<1:08:54,  7.53s/it]
#
#
#
#
#
#
#  25%|██▌       | 187/735 [58:45<1:29:21,  9.78s/it]
#
#
#
#
#
#
#  26%|██▌       | 188/735 [58:46<1:06:28,  7.29s/it]
#
#
#
#
#
#
#  26%|██▌       | 189/735 [1:00:02<4:13:49, 27.89s/it]
#
#
#
#
#
#
#  26%|██▌       | 190/735 [1:00:04<3:02:49, 20.13s/it]
#
#
#
#
#
#
#  26%|██▌       | 191/735 [1:00:06<2:13:30, 14.72s/it]
#
#
#
#
#
#
#  26%|██▌       | 192/735 [1:00:16<1:59:18, 13.18s/it]
#
#
#
#
#
#
#  26%|██▋       | 193/735 [1:00:16<1:25:06,  9.42s/it]
#
#
#
#
#
#
#  26%|██▋       | 194/735 [1:00:19<1:05:39,  7.28s/it]
#
#
#
#
#
#
#  27%|██▋       | 195/735 [1:00:19<46:57,  5.22s/it]
#
#
#
#
#
#
#  27%|██▋       | 196/735 [1:00:20<34:56,  3.89s/it]
#
#
#
#
#
#
#  27%|██▋       | 197/735 [1:00:22<29:26,  3.28s/it]
#
#
#
#
#
#
#  27%|██▋       | 198/735 [1:00:25<30:39,  3.43s/it]
#
#
#
#
#
#
#  27%|██▋       | 199/735 [1:00:41<1:02:14,  6.97s/it]
#
#
#
#
#
#
#  27%|██▋       | 200/735 [1:00:47<1:00:05,  6.74s/it]
#
#
#
#
#
#
#  27%|██▋       | 201/735 [1:00:47<42:41,  4.80s/it]
#
#
#
#
#
#
#  27%|██▋       | 202/735 [1:00:48<31:41,  3.57s/it]
#
#
#
#
#
#
#  28%|██▊       | 203/735 [1:00:49<26:05,  2.94s/it]
#
#
#
#
#
#
#  28%|██▊       | 204/735 [1:00:53<27:06,  3.06s/it]
#
#
#
#
#
#
#  28%|██▊       | 205/735 [1:00:54<23:29,  2.66s/it]
#
#
#
#
#
#
#  28%|██▊       | 206/735 [1:00:56<21:39,  2.46s/it]
#
#
#
#
#
#
#  28%|██▊       | 207/735 [1:00:58<19:01,  2.16s/it]
#
#
#
#
#
#
#  28%|██▊       | 209/735 [1:00:59<15:05,  1.72s/it]
#
#
#
#
#
#
#  29%|██▊       | 210/735 [1:01:00<12:11,  1.39s/it]
#
#
#
#
#
#
#  29%|██▊       | 211/735 [1:01:11<36:59,  4.24s/it]
#
#
#
#
#
#
#  29%|██▉       | 212/735 [1:01:15<36:26,  4.18s/it]
#
#
#
#
#
#
#  29%|██▉       | 213/735 [1:01:15<25:44,  2.96s/it]
#
#
#
#
#
#
#  29%|██▉       | 214/735 [1:01:34<1:07:53,  7.82s/it]
#
#
#
#
#
#
#  29%|██▉       | 215/735 [1:01:35<50:03,  5.78s/it]
#
#
#
#
#
#
#  29%|██▉       | 216/735 [1:01:37<39:02,  4.51s/it]
#
#
#
#
#
#
#  30%|██▉       | 217/735 [1:01:37<28:35,  3.31s/it]
#
#
#
#
#
#
#  30%|██▉       | 218/735 [1:01:47<44:21,  5.15s/it]
#
#
#
#
#
#
#  30%|██▉       | 219/735 [1:01:48<33:38,  3.91s/it]
#
#
#
#
#
#
#  30%|██▉       | 220/735 [1:01:52<34:48,  4.05s/it]
#
#
#
#
#
#
#  30%|███       | 221/735 [1:01:53<26:39,  3.11s/it]
#
#
#
#
#
#
#  30%|███       | 222/735 [1:01:54<21:59,  2.57s/it]
#
#
#
#
#
#
#  30%|███       | 223/735 [1:01:57<21:16,  2.49s/it]
#
#
#
#
#
#
#  30%|███       | 224/735 [1:01:58<17:49,  2.09s/it]
#
#
#
#
#
#
#  31%|███       | 225/735 [1:01:59<16:44,  1.97s/it]
#
#
#
#
#
#
#  31%|███       | 226/735 [1:02:01<15:44,  1.85s/it]
#
#
#
#
#
#
#  31%|███       | 227/735 [1:02:05<21:18,  2.52s/it]
#
#
#
#
#
#
#  31%|███       | 228/735 [1:02:06<17:57,  2.12s/it]
#
#
#
#
#
#
#  31%|███       | 229/735 [1:02:07<14:26,  1.71s/it]
#
#
#
#
#
#
#  31%|███▏      | 230/735 [1:02:19<39:42,  4.72s/it]
#
#
#
#
#
#
#  31%|███▏      | 231/735 [1:02:20<29:54,  3.56s/it]
#
#
#
#
#
#
#  32%|███▏      | 232/735 [1:02:35<59:44,  7.13s/it]
#
#
#
#
#
#
#  32%|███▏      | 233/735 [1:02:36<45:13,  5.40s/it]
#
#
#
#
#
#
#  32%|███▏      | 234/735 [1:02:37<34:00,  4.07s/it]
#
#
#
#
#
#
#  32%|███▏      | 235/735 [1:02:38<25:44,  3.09s/it]
#
#
#
#
#
#
#  32%|███▏      | 236/735 [1:02:39<19:16,  2.32s/it]
#
#
#
#
#
#
#  32%|███▏      | 238/735 [1:02:39<14:14,  1.72s/it]
#
#
#
#
#
#
#  33%|███▎      | 239/735 [1:02:40<11:24,  1.38s/it]
#
#
#
#
#
#
#  33%|███▎      | 240/735 [1:02:41<09:27,  1.15s/it]
#
#
#
#
#
#
#  33%|███▎      | 241/735 [1:02:42<10:11,  1.24s/it]
#
#
#
#
#
#
#  33%|███▎      | 242/735 [1:02:42<08:02,  1.02it/s]
#
#
#
#
#
#
#  33%|███▎      | 243/735 [1:02:43<07:56,  1.03it/s]
#
#
#
#
#
#
#  33%|███▎      | 244/735 [1:02:44<06:20,  1.29it/s]
#
#
#
#
#
#
#  33%|███▎      | 245/735 [1:02:50<19:27,  2.38s/it]
#
#
#
#
#
#
#  33%|███▎      | 246/735 [1:02:51<15:49,  1.94s/it]
#
#
#
#
#
#
#  34%|███▎      | 247/735 [1:02:52<13:08,  1.62s/it]
#
#
#
#
#
#
#  34%|███▎      | 248/735 [1:02:52<11:21,  1.40s/it]
#
#
#
#
#
#
#  34%|███▍      | 249/735 [1:02:55<13:26,  1.66s/it]
#
#
#
#
#
#
#  34%|███▍      | 250/735 [1:02:57<14:24,  1.78s/it]
#
#
#
#
#
#
#  34%|███▍      | 251/735 [1:03:01<20:56,  2.60s/it]
#
#
#
#
#
#
#  34%|███▍      | 252/735 [1:03:03<18:03,  2.24s/it]
#
#
#
#
#
#
#  34%|███▍      | 253/735 [1:03:05<17:24,  2.17s/it]
#
#
#
#
#
#
#  35%|███▍      | 254/735 [1:03:06<16:21,  2.04s/it]
#
#
#
#
#
#
#  35%|███▍      | 255/735 [1:03:07<13:27,  1.68s/it]
#
#
#
#
#
#
#  35%|███▍      | 256/735 [1:03:09<13:55,  1.74s/it]
#
#
#
#
#
#
#  35%|███▍      | 257/735 [1:03:10<12:36,  1.58s/it]
#
#
#
#
#
#
#  35%|███▌      | 258/735 [1:03:14<18:25,  2.32s/it]
#
#
#
#
#
#
#  35%|███▌      | 259/735 [1:03:15<13:59,  1.76s/it]
#
#
#
#
#
#
#  35%|███▌      | 260/735 [1:03:16<11:22,  1.44s/it]
#
#
#
#
#
#
#  36%|███▌      | 261/735 [1:03:16<08:16,  1.05s/it]
#
#
#
#
#
#
#  36%|███▌      | 262/735 [1:03:17<09:23,  1.19s/it]
#
#
#
#
#
#
#  36%|███▌      | 263/735 [1:03:22<16:42,  2.12s/it]
#
#
#
#
#
#
#  36%|███▌      | 264/735 [1:03:23<14:14,  1.81s/it]
#
#
#
#
#
#
#  36%|███▌      | 265/735 [1:03:31<29:25,  3.76s/it]
#
#
#
#
#
#
#  36%|███▌      | 266/735 [1:03:33<26:36,  3.40s/it]
#
#
#
#
#
#
#  36%|███▋      | 267/735 [1:03:34<19:59,  2.56s/it]
#
#
#
#
#
#
#  36%|███▋      | 268/735 [1:03:39<25:31,  3.28s/it]
#
#
#
#
#
#
#  37%|███▋      | 269/735 [1:03:39<18:11,  2.34s/it]
#
#
#
#
#
#
#  37%|███▋      | 270/735 [1:03:42<18:54,  2.44s/it]
#
#
#
#
#
#
#  37%|███▋      | 271/735 [1:03:43<14:47,  1.91s/it]
#
#
#
#
#
#
#  37%|███▋      | 272/735 [1:03:44<13:13,  1.71s/it]
#
#
#
#
#
#
#  37%|███▋      | 273/735 [1:03:44<09:58,  1.29s/it]
#
#
#
#
#
#
#  37%|███▋      | 274/735 [1:03:45<08:14,  1.07s/it]
#
#
#
#
#
#
#  37%|███▋      | 275/735 [1:03:47<11:24,  1.49s/it]
#
#
#
#
#
#
#  38%|███▊      | 276/735 [1:04:02<42:08,  5.51s/it]
#
#
#
#
#
#
#  38%|███▊      | 277/735 [1:04:10<47:11,  6.18s/it]
#
#
#
#
#
#
#  38%|███▊      | 278/735 [1:04:10<33:17,  4.37s/it]
#
#
#
#
#
#
#  38%|███▊      | 279/735 [1:04:11<25:14,  3.32s/it]
#
#
#
#
#
#
#  38%|███▊      | 280/735 [1:04:11<18:57,  2.50s/it]
#
#
#
#
#
#
#  38%|███▊      | 281/735 [1:04:17<25:39,  3.39s/it]
#
#
#
#
#
#
#  38%|███▊      | 282/735 [1:04:21<26:22,  3.49s/it]
#
#
#
#
#
#
#  39%|███▊      | 283/735 [1:04:23<22:50,  3.03s/it]
#
#
#
#
#
#
#  39%|███▊      | 284/735 [1:04:23<17:41,  2.35s/it]
#
#
#
#
#
#
#  39%|███▉      | 285/735 [1:04:23<12:46,  1.70s/it]
#
#
#
#
#
#
#  39%|███▉      | 286/735 [1:04:25<11:30,  1.54s/it]
#
#
#
#
#
#
#  39%|███▉      | 287/735 [1:04:27<13:56,  1.87s/it]
#
#
#
#
#
#
#  39%|███▉      | 288/735 [1:04:29<13:36,  1.83s/it]
#
#
#
#
#
#
#  39%|███▉      | 289/735 [1:04:31<13:06,  1.76s/it]
#
#
#
#
#
#
#  39%|███▉      | 290/735 [1:04:34<16:30,  2.23s/it]
#
#
#
#
#
#
#  40%|███▉      | 291/735 [1:04:36<15:20,  2.07s/it]
#
#
#
#
#
#
#  40%|███▉      | 292/735 [1:04:37<14:44,  2.00s/it]
#
#
#
#
#
#
#  40%|███▉      | 293/735 [1:04:39<13:00,  1.77s/it]
#
#
#
#
#
#
#  40%|████      | 294/735 [1:04:40<12:33,  1.71s/it]
#
#
#
#
#
#
#  40%|████      | 295/735 [1:04:41<09:38,  1.31s/it]
#
#
#
#
#
#
#  40%|████      | 296/735 [1:04:53<34:42,  4.74s/it]
#
#
#
#
#
#
#  40%|████      | 297/735 [1:18:12<29:32:53, 242.86s/it]
#
#
#
#
#
#
#  41%|████      | 298/735 [1:18:15<20:44:42, 170.90s/it]
#
#
#
#
#
#
#  41%|████      | 299/735 [1:18:21<14:42:09, 121.40s/it]
#
#
#
#
#
#
#  41%|████      | 300/735 [1:18:25<10:25:52, 86.33s/it]
#
#
#
#
#
#
#  41%|████      | 303/735 [1:18:25<7:15:10, 60.44s/it]
#
#
#
#
#
#
#  41%|████▏     | 304/735 [1:18:26<5:04:29, 42.39s/it]
#
#
#
#
#
#
#  41%|████▏     | 305/735 [1:18:26<3:32:54, 29.71s/it]
#
#
#
#
#
#
#  42%|████▏     | 306/735 [1:18:26<2:29:19, 20.89s/it]
#
#
#
#
#
#
#  42%|████▏     | 311/735 [1:18:26<1:43:28, 14.64s/it]
#
#
#
#
#
#
#  43%|████▎     | 315/735 [1:18:28<1:12:38, 10.38s/it]
#
#
#
#
#
#
#  44%|████▍     | 322/735 [1:18:28<50:02,  7.27s/it]
#
#
#
#
#
#
#  44%|████▍     | 325/735 [1:18:29<35:07,  5.14s/it]
#
#
#
#
#
#
#  45%|████▌     | 334/735 [1:18:29<24:08,  3.61s/it]
#
#
#
#
#
#
#  47%|████▋     | 343/735 [1:18:29<16:32,  2.53s/it]
#
#
#
#
#
#
#  48%|████▊     | 351/735 [1:18:29<11:22,  1.78s/it]
#
#
#
#
#
#
#  49%|████▉     | 360/735 [1:18:29<07:47,  1.25s/it]
#
#
#
#
#
#
#  50%|█████     | 369/735 [1:18:30<05:20,  1.14it/s]
#
#
#
#
#
#
#  51%|█████     | 376/735 [1:18:31<04:03,  1.48it/s]
#
#
#
#
#
#
#  52%|█████▏    | 381/735 [1:18:34<03:41,  1.60it/s]
#
#
#
#
#
#
#  52%|█████▏    | 385/735 [1:18:34<02:52,  2.03it/s]
#
#
#
#
#
#
#  53%|█████▎    | 388/735 [1:18:34<02:04,  2.79it/s]
#
#
#
#
#
#
#  53%|█████▎    | 391/735 [1:18:36<02:15,  2.53it/s]
#
#
#
#
#
#
#  53%|█████▎    | 393/735 [1:18:37<02:18,  2.47it/s]
#
#
#
#
#
#
#  54%|█████▍    | 399/735 [1:18:37<01:37,  3.45it/s]
#
#
#
#
#
#
#  55%|█████▍    | 402/735 [1:18:40<02:43,  2.03it/s]
#
#
#
#
#
#
#  55%|█████▍    | 404/735 [1:18:49<09:13,  1.67s/it]
#
#
#
#
#
#
#  55%|█████▌    | 406/735 [1:18:55<11:39,  2.13s/it]
#
#
#
#
#
#
#  55%|█████▌    | 407/735 [1:18:57<11:06,  2.03s/it]
#
#
#
#
#
#
#  56%|█████▌    | 408/735 [1:19:01<15:06,  2.77s/it]
#
#
#
#
#
#
#  56%|█████▌    | 409/735 [1:19:06<18:17,  3.37s/it]
#
#
#
#
#
#
#  56%|█████▌    | 410/735 [1:19:12<21:43,  4.01s/it]
#
#
#
#
#
#
#  56%|█████▌    | 411/735 [1:19:25<36:24,  6.74s/it]
#
#
#
#
#
#
#  56%|█████▌    | 412/735 [1:19:28<30:59,  5.76s/it]
#
#
#
#
#
#
#  56%|█████▌    | 413/735 [1:19:29<23:06,  4.31s/it]
#
#
#
#
#
#
#  56%|█████▋    | 414/735 [1:19:31<19:27,  3.64s/it]
#
#
#
#
#
#
#  56%|█████▋    | 415/735 [1:19:32<15:18,  2.87s/it]
#
#
#
#
#
#
#  57%|█████▋    | 416/735 [1:19:33<11:48,  2.22s/it]
#
#
#
#
#
#
#  57%|█████▋    | 417/735 [1:19:43<24:02,  4.54s/it]
#
#
#
#
#
#
#  57%|█████▋    | 418/735 [1:19:46<21:50,  4.13s/it]
#
#
#
#
#
#
#  57%|█████▋    | 419/735 [1:19:47<17:02,  3.24s/it]
#
#
#
#
#
#
#  57%|█████▋    | 420/735 [1:19:49<14:13,  2.71s/it]
#
#
#
#
#
#
#  57%|█████▋    | 421/735 [1:19:52<15:45,  3.01s/it]
#
#
#
#
#
#
#  57%|█████▋    | 422/735 [1:19:56<16:37,  3.19s/it]
#
#
#
#
#
#
#  58%|█████▊    | 423/735 [1:19:57<12:42,  2.44s/it]
#
#
#
#
#
#
#  58%|█████▊    | 424/735 [1:20:05<22:20,  4.31s/it]
#
#
#
#
#
#
#  58%|█████▊    | 425/735 [1:20:27<48:34,  9.40s/it]
#
#
#
#
#
#
#  58%|█████▊    | 426/735 [1:20:28<35:19,  6.86s/it]
#
#
#
#
#
#
#  58%|█████▊    | 427/735 [1:20:30<27:52,  5.43s/it]
#
#
#
#
#
#
#  58%|█████▊    | 428/735 [1:20:36<29:33,  5.78s/it]
#
#
#
#
#
#
#  58%|█████▊    | 429/735 [1:20:49<40:32,  7.95s/it]
#
#
#
#
#
#
#  59%|█████▊    | 430/735 [1:21:05<51:34, 10.15s/it]
#
#
#
#
#
#
#  59%|█████▊    | 431/735 [1:21:11<45:39,  9.01s/it]
#
#
#
#
#
#
#  59%|█████▉    | 432/735 [1:21:12<32:45,  6.49s/it]
#
#
#
#
#
#
#  59%|█████▉    | 433/735 [1:21:12<23:51,  4.74s/it]
#
#
#
#
#
#
#  59%|█████▉    | 434/735 [1:21:18<25:31,  5.09s/it]
#
#
#
#
#
#
#  59%|█████▉    | 435/735 [1:21:20<21:08,  4.23s/it]
#
#
#
#
#
#
#  59%|█████▉    | 436/735 [1:21:26<22:50,  4.58s/it]
#
#
#
#
#
#
#  60%|█████▉    | 438/735 [1:21:26<16:08,  3.26s/it]
#
#
#
#
#
#
#  60%|█████▉    | 439/735 [1:21:29<16:00,  3.24s/it]
#
#
#
#
#
#
#  60%|█████▉    | 440/735 [1:21:43<32:02,  6.52s/it]
#
#
#
#
#
#
#  60%|██████    | 441/735 [1:21:44<22:59,  4.69s/it]
#
#
#
#
#
#
#  60%|██████    | 442/735 [1:21:46<19:19,  3.96s/it]
#
#
#
#
#
#
#  60%|██████    | 443/735 [1:21:46<14:00,  2.88s/it]
#
#
#
#
#
#
#  60%|██████    | 444/735 [1:21:49<14:09,  2.92s/it]
#
#
#
#
#
#
#  61%|██████    | 445/735 [1:21:54<15:57,  3.30s/it]
#
#
#
#
#
#
#  61%|██████    | 446/735 [1:21:54<11:29,  2.38s/it]
#
#
#
#
#
#
#  61%|██████    | 447/735 [1:21:58<13:40,  2.85s/it]
#
#
#
#
#
#
#  61%|██████    | 448/735 [1:22:07<21:57,  4.59s/it]
#
#
#
#
#
#
#  61%|██████    | 449/735 [1:22:10<20:53,  4.38s/it]
#
#
#
#
#
#
#  61%|██████    | 450/735 [1:22:15<20:28,  4.31s/it]
#
#
#
#
#
#
#  61%|██████▏   | 451/735 [1:22:20<21:59,  4.64s/it]
#
#
#
#
#
#
#  61%|██████▏   | 452/735 [1:22:26<24:15,  5.14s/it]
#
#
#
#
#
#
#  62%|██████▏   | 453/735 [1:22:27<18:36,  3.96s/it]
#
#
#
#
#
#
#  62%|██████▏   | 454/735 [1:22:35<23:55,  5.11s/it]
#
#
#
#
#
#
#  62%|██████▏   | 455/735 [1:22:44<28:58,  6.21s/it]
#
#
#
#
#
#
#  62%|██████▏   | 456/735 [1:23:06<50:50, 10.93s/it]
#
#
#
#
#
#
#  62%|██████▏   | 457/735 [1:23:09<40:00,  8.63s/it]
#
#
#
#
#
#
#  62%|██████▏   | 458/735 [1:23:13<33:29,  7.26s/it]
#
#
#
#
#
#
#  62%|██████▏   | 459/735 [1:23:14<23:53,  5.19s/it]
#
#
#
#
#
#
#  63%|██████▎   | 460/735 [1:23:14<17:15,  3.77s/it]
#
#
#
#
#
#
#  63%|██████▎   | 462/735 [1:23:16<13:18,  2.93s/it]
#
#
#
#
#
#
#  63%|██████▎   | 463/735 [1:23:17<11:04,  2.44s/it]
#
#
#
#
#
#
#  63%|██████▎   | 464/735 [1:23:18<08:55,  1.97s/it]
#
#
#
#
#
#
#  63%|██████▎   | 465/735 [1:23:22<10:50,  2.41s/it]
#
#
#
#
#
#
#  63%|██████▎   | 466/735 [1:23:25<11:27,  2.56s/it]
#
#
#
#
#
#
#  64%|██████▎   | 467/735 [1:23:29<14:00,  3.14s/it]
#
#
#
#
#
#
#  64%|██████▎   | 468/735 [1:23:36<18:30,  4.16s/it]
#
#
#
#
#
#
#  64%|██████▍   | 469/735 [1:23:40<18:11,  4.10s/it]
#
#
#
#
#
#
#  64%|██████▍   | 470/735 [1:23:42<15:30,  3.51s/it]
#
#
#
#
#
#
#  64%|██████▍   | 471/735 [1:23:43<13:01,  2.96s/it]
#
#
#
#
#
#
#  64%|██████▍   | 472/735 [1:23:47<13:12,  3.01s/it]
#
#
#
#
#
#
#  64%|██████▍   | 473/735 [1:23:48<10:33,  2.42s/it]
#
#
#
#
#
#
#  64%|██████▍   | 474/735 [1:23:49<09:32,  2.19s/it]
#
#
#
#
#
#
#  65%|██████▍   | 475/735 [1:23:51<08:19,  1.92s/it]
#
#
#
#
#
#
#  65%|██████▍   | 476/735 [1:23:53<08:55,  2.07s/it]
#
#
#
#
#
#
#  65%|██████▍   | 477/735 [1:24:00<15:30,  3.61s/it]
#
#
#
#
#
#
#  65%|██████▌   | 478/735 [1:24:02<13:02,  3.04s/it]
#
#
#
#
#
#
#  65%|██████▌   | 479/735 [1:24:04<12:23,  2.90s/it]
#
#
#
#
#
#
#  65%|██████▌   | 480/735 [1:24:05<09:38,  2.27s/it]
#
#
#
#
#
#
#  65%|██████▌   | 481/735 [1:24:07<09:13,  2.18s/it]
#
#
#
#
#
#
#  66%|██████▌   | 482/735 [1:24:11<11:39,  2.76s/it]
#
#
#
#
#
#
#  66%|██████▌   | 483/735 [1:25:16<1:29:38, 21.34s/it]
#
#
#
#
#
#
#  66%|██████▌   | 484/735 [1:25:17<1:03:15, 15.12s/it]
#
#
#
#
#
#
#  66%|██████▌   | 485/735 [1:25:18<45:39, 10.96s/it]
#
#
#
#
#
#
#  66%|██████▌   | 486/735 [1:25:24<39:02,  9.41s/it]
#
#
#
#
#
#
#  66%|██████▋   | 487/735 [1:25:27<31:17,  7.57s/it]
#
#
#
#
#
#
#  66%|██████▋   | 488/735 [1:25:28<23:08,  5.62s/it]
#
#
#
#
#
#
#  67%|██████▋   | 489/735 [1:25:28<16:26,  4.01s/it]
#
#
#
#
#
#
#  67%|██████▋   | 490/735 [1:25:37<22:18,  5.46s/it]
#
#
#
#
#
#
#  67%|██████▋   | 491/735 [1:25:42<21:46,  5.36s/it]
#
#
#
#
#
#
#  67%|██████▋   | 492/735 [1:25:50<24:16,  5.99s/it]
#
#
#
#
#
#
#  67%|██████▋   | 493/735 [1:25:51<18:43,  4.64s/it]
#
#
#
#
#
#
#  67%|██████▋   | 494/735 [1:25:52<13:42,  3.41s/it]
#
#
#
#
#
#
#  67%|██████▋   | 495/735 [1:25:57<15:48,  3.95s/it]
#
#
#
#
#
#
#  67%|██████▋   | 496/735 [1:26:37<59:07, 14.85s/it]
#
#
#
#
#
#
#  68%|██████▊   | 497/735 [1:26:39<43:18, 10.92s/it]
#
#
#
#
#
#
#  68%|██████▊   | 498/735 [1:26:44<36:34,  9.26s/it]
#
#
#
#
#
#
#  68%|██████▊   | 499/735 [1:26:55<38:00,  9.66s/it]
#
#
#
#
#
#
#  68%|██████▊   | 500/735 [1:26:57<28:30,  7.28s/it]
#
#
#
#
#
#
#  68%|██████▊   | 501/735 [1:27:00<24:09,  6.19s/it]
#
#
#
#
#
#
#  68%|██████▊   | 502/735 [1:27:05<22:01,  5.67s/it]
#
#
#
#
#
#
#  68%|██████▊   | 503/735 [1:27:18<30:55,  8.00s/it]
#
#
#
#
#
#
#  69%|██████▊   | 504/735 [1:27:23<26:54,  6.99s/it]
#
#
#
#
#
#
#  69%|██████▊   | 505/735 [1:27:40<38:15,  9.98s/it]
#
#
#
#
#
#
#  69%|██████▉   | 506/735 [1:27:40<26:55,  7.06s/it]
#
#
#
#
#
#
#  69%|██████▉   | 507/735 [1:28:02<44:18, 11.66s/it]
#
#
#
#
#
#
#  69%|██████▉   | 508/735 [1:28:20<50:45, 13.42s/it]
#
#
#
#
#
#
#  69%|██████▉   | 509/735 [1:28:21<36:54,  9.80s/it]
#
#
#
#
#
#
#  69%|██████▉   | 510/735 [1:28:23<27:17,  7.28s/it]
#
#
#
#
#
#
#  70%|██████▉   | 511/735 [1:28:24<20:46,  5.56s/it]
#
#
#
#
#
#
#  70%|██████▉   | 512/735 [1:28:31<22:19,  6.01s/it]
#
#
#
#
#
#
#  70%|██████▉   | 513/735 [1:28:32<16:47,  4.54s/it]
#
#
#
#
#
#
#  70%|██████▉   | 514/735 [1:28:38<17:45,  4.82s/it]
#
#
#
#
#
#
#  70%|███████   | 515/735 [1:28:46<21:10,  5.78s/it]
#
#
#
#
#
#
#  70%|███████   | 516/735 [1:28:47<15:58,  4.38s/it]
#
#
#
#
#
#
#  70%|███████   | 517/735 [1:28:51<15:46,  4.34s/it]
#
#
#
#
#
#
#  70%|███████   | 518/735 [1:28:54<14:14,  3.94s/it]
#
#
#
#
#
#
#  71%|███████   | 519/735 [1:28:54<10:04,  2.80s/it]
#
#
#
#
#
#
#  71%|███████   | 520/735 [1:28:55<07:49,  2.18s/it]
#
#
#
#
#
#
#  71%|███████   | 521/735 [1:28:55<05:40,  1.59s/it]
#
#
#
#
#
#
#  71%|███████   | 522/735 [1:28:56<04:51,  1.37s/it]
#
#
#
#
#
#
#  71%|███████   | 523/735 [1:28:58<05:25,  1.53s/it]
#
#
#
#
#
#
#  71%|███████▏  | 524/735 [1:29:02<07:45,  2.21s/it]
#
#
#
#
#
#
#  71%|███████▏  | 525/735 [1:29:09<12:29,  3.57s/it]
#
#
#
#
#
#
#  72%|███████▏  | 526/735 [1:29:12<12:21,  3.55s/it]
#
#
#
#
#
#
#  72%|███████▏  | 527/735 [1:29:16<12:06,  3.49s/it]
#
#
#
#
#
#
#  72%|███████▏  | 528/735 [1:29:19<12:19,  3.57s/it]
#
#
#
#
#
#
#  72%|███████▏  | 529/735 [1:29:20<09:02,  2.64s/it]
#
#
#
#
#
#
#  72%|███████▏  | 530/735 [1:29:23<09:57,  2.91s/it]
#
#
#
#
#
#
#  72%|███████▏  | 531/735 [1:29:26<09:25,  2.77s/it]
#
#
#
#
#
#
#  72%|███████▏  | 532/735 [1:29:26<07:09,  2.12s/it]
#
#
#
#
#
#
#  73%|███████▎  | 533/735 [1:29:32<10:43,  3.18s/it]
#
#
#
#
#
#
#  73%|███████▎  | 534/735 [1:29:35<09:59,  2.98s/it]
#
#
#
#
#
#
#  73%|███████▎  | 535/735 [1:29:45<17:34,  5.27s/it]
#
#
#
#
#
#
#  73%|███████▎  | 536/735 [1:29:48<14:58,  4.52s/it]
#
#
#
#
#
#
#  73%|███████▎  | 537/735 [1:30:05<27:33,  8.35s/it]
#
#
#
#
#
#
#  73%|███████▎  | 538/735 [1:30:12<26:14,  7.99s/it]
#
#
#
#
#
#
#  73%|███████▎  | 539/735 [1:30:21<27:13,  8.34s/it]
#
#
#
#
#
#
#  73%|███████▎  | 540/735 [1:30:23<20:09,  6.20s/it]
#
#
#
#
#
#
#  74%|███████▎  | 541/735 [1:30:28<19:19,  5.97s/it]
#
#
#
#
#
#
#  74%|███████▎  | 542/735 [1:30:32<16:42,  5.19s/it]
#
#
#
#
#
#
#  74%|███████▍  | 543/735 [1:30:33<12:51,  4.02s/it]
#
#
#
#
#
#
#  74%|███████▍  | 544/735 [1:30:35<11:19,  3.56s/it]
#
#
#
#
#
#
#  74%|███████▍  | 546/735 [1:30:36<08:11,  2.60s/it]
#
#
#
#
#
#
#  74%|███████▍  | 547/735 [1:30:46<15:21,  4.90s/it]
#
#
#
#
#
#
#  75%|███████▍  | 548/735 [1:30:53<17:21,  5.57s/it]
#
#
#
#
#
#
#  75%|███████▍  | 549/735 [1:30:54<12:17,  3.96s/it]
#
#
#
#
#
#
#  75%|███████▍  | 550/735 [1:31:00<14:23,  4.67s/it]
#
#
#
#
#
#
#  75%|███████▍  | 551/735 [1:31:03<12:33,  4.09s/it]
#
#
#
#
#
#
#  75%|███████▌  | 552/735 [1:31:08<13:48,  4.53s/it]
#
#
#
#
#
#
#  75%|███████▌  | 554/735 [1:31:09<09:45,  3.24s/it]
#
#
#
#
#
#
#  76%|███████▌  | 555/735 [1:31:11<08:35,  2.86s/it]
#
#
#
#
#
#
#  76%|███████▌  | 556/735 [1:31:21<15:16,  5.12s/it]
#
#
#
#
#
#
#  76%|███████▌  | 557/735 [1:31:30<18:46,  6.33s/it]
#
#
#
#
#
#
#  76%|███████▌  | 558/735 [1:31:32<14:52,  5.04s/it]
#
#
#
#
#
#
#  76%|███████▌  | 559/735 [1:31:38<15:32,  5.30s/it]
#
#
#
#
#
#
#  76%|███████▌  | 560/735 [1:31:40<12:12,  4.19s/it]
#
#
#
#
#
#
#  76%|███████▋  | 561/735 [1:31:40<09:04,  3.13s/it]
#
#
#
#
#
#
#  76%|███████▋  | 562/735 [1:31:42<07:17,  2.53s/it]
#
#
#
#
#
#
#  77%|███████▋  | 563/735 [1:31:43<06:39,  2.32s/it]
#
#
#
#
#
#
#  77%|███████▋  | 564/735 [1:31:53<13:14,  4.65s/it]
#
#
#
#
#
#
#  77%|███████▋  | 565/735 [1:31:56<11:19,  4.00s/it]
#
#
#
#
#
#
#  77%|███████▋  | 566/735 [1:31:57<08:29,  3.02s/it]
#
#
#
#
#
#
#  77%|███████▋  | 567/735 [1:31:58<06:59,  2.50s/it]
#
#
#
#
#
#
#  77%|███████▋  | 568/735 [1:32:00<06:40,  2.40s/it]
#
#
#
#
#
#
#  77%|███████▋  | 569/735 [1:32:02<05:55,  2.14s/it]
#
#
#
#
#
#
#  78%|███████▊  | 570/735 [1:32:06<07:30,  2.73s/it]
#
#
#
#
#
#
#  78%|███████▊  | 571/735 [1:32:09<07:40,  2.81s/it]
#
#
#
#
#
#
#  78%|███████▊  | 572/735 [1:32:14<09:45,  3.59s/it]
#
#
#
#
#
#
#  78%|███████▊  | 573/735 [1:32:19<10:33,  3.91s/it]
#
#
#
#
#
#
#  78%|███████▊  | 574/735 [1:32:20<08:23,  3.13s/it]
#
#
#
#
#
#
#  78%|███████▊  | 575/735 [1:32:20<06:02,  2.27s/it]
#
#
#
#
#
#
#  78%|███████▊  | 576/735 [1:32:22<05:26,  2.05s/it]
#
#
#
#
#
#
#  79%|███████▊  | 577/735 [1:32:22<03:55,  1.49s/it]
#
#
#
#
#
#
#  79%|███████▊  | 578/735 [1:32:24<04:15,  1.62s/it]
#
#
#
#
#
#
#  79%|███████▉  | 579/735 [1:32:25<03:44,  1.44s/it]
#
#
#
#
#
#
#  79%|███████▉  | 580/735 [1:32:28<04:53,  1.89s/it]
#
#
#
#
#
#
#  79%|███████▉  | 581/735 [1:32:34<07:54,  3.08s/it]
#
#
#
#
#
#
#  79%|███████▉  | 582/735 [1:32:35<06:28,  2.54s/it]
#
#
#
#
#
#
#  79%|███████▉  | 583/735 [1:32:36<05:14,  2.07s/it]
#
#
#
#
#
#
#  79%|███████▉  | 584/735 [1:32:40<06:13,  2.47s/it]
#
#
#
#
#
#
#  80%|███████▉  | 585/735 [1:32:40<04:26,  1.77s/it]
#
#
#
#
#
#
#  80%|███████▉  | 586/735 [1:32:40<03:23,  1.36s/it]
#
#
#
#
#
#
#  80%|███████▉  | 587/735 [1:32:44<05:19,  2.16s/it]
#
#
#
#
#
#
#  80%|████████  | 588/735 [1:32:44<03:49,  1.56s/it]
#
#
#
#
#
#
#  80%|████████  | 589/735 [1:32:45<03:13,  1.32s/it]
#
#
#
#
#
#
#  80%|████████  | 590/735 [1:32:50<05:53,  2.44s/it]
#
#
#
#
#
#
#  80%|████████  | 591/735 [1:32:50<04:14,  1.77s/it]
#
#
#
#
#
#
#  81%|████████  | 592/735 [1:32:51<03:33,  1.49s/it]
#
#
#
#
#
#
#  81%|████████  | 593/735 [1:32:51<02:32,  1.08s/it]
#
#
#
#
#
#
#  81%|████████  | 594/735 [1:32:52<02:37,  1.12s/it]
#
#
#
#
#
#
#  81%|████████  | 595/735 [1:32:54<02:34,  1.11s/it]
#
#
#
#
#
#
#  81%|████████  | 596/735 [1:32:54<02:21,  1.02s/it]
#
#
#
#
#
#
#  81%|████████  | 597/735 [1:32:56<02:42,  1.17s/it]
#
#
#
#
#
#
#  81%|████████▏ | 598/735 [1:32:58<03:00,  1.32s/it]
#
#
#
#
#
#
#  81%|████████▏ | 599/735 [1:33:02<04:57,  2.18s/it]
#
#
#
#
#
#
#  82%|████████▏ | 600/735 [1:33:02<03:53,  1.73s/it]
#
#
#
#
#
#
#  82%|████████▏ | 601/735 [1:33:03<03:08,  1.41s/it]
#
#
#
#
#
#
#  82%|████████▏ | 602/735 [1:33:05<03:37,  1.63s/it]
#
#
#
#
#
#
#  82%|████████▏ | 603/735 [1:33:20<12:03,  5.48s/it]
#
#
#
#
#
#
#  82%|████████▏ | 604/735 [1:33:20<08:34,  3.93s/it]
#
#
#
#
#
#
#  82%|████████▏ | 605/735 [1:33:20<06:15,  2.89s/it]
#
#
#
#
#
#
#  82%|████████▏ | 606/735 [1:34:48<1:00:31, 28.15s/it]
#
#
#
#
#
#
#  83%|████████▎ | 607/735 [1:34:49<43:14, 20.27s/it]
#
#
#
#
#
#
#  83%|████████▎ | 608/735 [1:34:50<30:17, 14.31s/it]
#
#
#
#
#
#
#  83%|████████▎ | 609/735 [1:34:50<21:25, 10.20s/it]
#
#
#
#
#
#
#  83%|████████▎ | 610/735 [1:34:54<16:58,  8.15s/it]
#
#
#
#
#
#
#  83%|████████▎ | 611/735 [1:34:55<12:39,  6.13s/it]
#
#
#
#
#
#
#  83%|████████▎ | 612/735 [1:34:58<10:30,  5.13s/it]
#
#
#
#
#
#
#  83%|████████▎ | 613/735 [1:34:59<08:09,  4.01s/it]
#
#
#
#
#
#
#  84%|████████▎ | 614/735 [1:35:01<06:33,  3.26s/it]
#
#
#
#
#
#
#  84%|████████▎ | 615/735 [1:35:01<04:39,  2.33s/it]
#
#
#
#
#
#
#  84%|████████▍ | 616/735 [1:35:05<05:19,  2.69s/it]
#
#
#
#
#
#
#  84%|████████▍ | 617/735 [1:35:08<05:28,  2.79s/it]
#
#
#
#
#
#
#  84%|████████▍ | 618/735 [1:35:09<04:19,  2.22s/it]
#
#
#
#
#
#
#  84%|████████▍ | 619/735 [1:35:10<03:39,  1.89s/it]
#
#
#
#
#
#
#  84%|████████▍ | 620/735 [1:35:10<02:50,  1.48s/it]
#
#
#
#
#
#
#  84%|████████▍ | 621/735 [1:35:11<02:30,  1.32s/it]
#
#
#
#
#
#
#  85%|████████▍ | 622/735 [1:35:12<02:00,  1.06s/it]
#
#
#
#
#
#
#  85%|████████▍ | 623/735 [1:35:12<01:30,  1.24it/s]
#
#
#
#
#
#
#  85%|████████▍ | 624/735 [1:35:13<01:54,  1.03s/it]
#
#
#
#
#
#
#  85%|████████▌ | 625/735 [1:35:18<03:50,  2.10s/it]
#
#
#
#
#
#
#  85%|████████▌ | 626/735 [1:35:23<05:41,  3.13s/it]
#
#
#
#
#
#
#  85%|████████▌ | 627/735 [1:35:25<04:46,  2.65s/it]
#
#
#
#
#
#
#  85%|████████▌ | 628/735 [1:35:26<03:40,  2.06s/it]
#
#
#
#
#
#
#  86%|████████▌ | 629/735 [1:35:30<05:04,  2.87s/it]
#
#
#
#
#
#
#  86%|████████▌ | 630/735 [1:35:34<05:10,  2.96s/it]
#
#
#
#
#
#
#  86%|████████▌ | 631/735 [1:35:40<06:39,  3.85s/it]
#
#
#
#
#
#
#  86%|████████▌ | 632/735 [1:35:40<04:57,  2.88s/it]
#
#
#
#
#
#
#  86%|████████▌ | 633/735 [1:35:57<12:09,  7.15s/it]
#
#
#
#
#
#
#  86%|████████▋ | 634/735 [1:36:14<17:05, 10.15s/it]
#
#
#
#
#
#
#  86%|████████▋ | 635/735 [1:36:15<11:58,  7.18s/it]
#
#
#
#
#
#
#  87%|████████▋ | 636/735 [1:36:16<08:42,  5.28s/it]
#
#
#
#
#
#
#  87%|████████▋ | 637/735 [1:36:16<06:07,  3.75s/it]
#
#
#
#
#
#
#  87%|████████▋ | 639/735 [1:36:21<05:33,  3.48s/it]
#
#
#
#
#
#
#  87%|████████▋ | 640/735 [1:36:26<05:55,  3.75s/it]
#
#
#
#
#
#
#  87%|████████▋ | 641/735 [1:36:31<06:27,  4.12s/it]
#
#
#
#
#
#
#  87%|████████▋ | 642/735 [1:36:35<06:13,  4.01s/it]
#
#
#
#
#
#
#  87%|████████▋ | 643/735 [1:36:40<06:43,  4.39s/it]
#
#
#
#
#
#
#  88%|████████▊ | 644/735 [1:36:46<07:18,  4.82s/it]
#
#
#
#
#
#
#  88%|████████▊ | 645/735 [1:36:53<08:31,  5.68s/it]
#
#
#
#
#
#
#  88%|████████▊ | 646/735 [1:37:01<09:09,  6.17s/it]
#
#
#
#
#
#
#  88%|████████▊ | 647/735 [1:37:04<07:54,  5.39s/it]
#
#
#
#
#
#
#  88%|████████▊ | 648/735 [1:38:16<36:46, 25.36s/it]
#
#
#
#
#
#
#  88%|████████▊ | 649/735 [1:38:34<33:15, 23.20s/it]
#
#
#
#
#
#
#  89%|████████▊ | 651/735 [1:38:40<24:00, 17.14s/it]
#
#
#
#
#
#
#  89%|████████▊ | 652/735 [1:38:43<17:46, 12.85s/it]
#
#
#
#
#
#
#  89%|████████▉ | 653/735 [1:38:50<14:56, 10.93s/it]
#
#
#
#
#
#
#  89%|████████▉ | 654/735 [1:38:54<12:14,  9.07s/it]
#
#
#
#
#
#
#  89%|████████▉ | 655/735 [1:39:08<13:47, 10.34s/it]
#
#
#
#
#
#
#  89%|████████▉ | 656/735 [1:39:11<11:03,  8.39s/it]
#
#
#
#
#
#
#  89%|████████▉ | 657/735 [1:39:19<10:27,  8.05s/it]
#
#
#
#
#
#
#  90%|████████▉ | 658/735 [1:39:33<12:35,  9.81s/it]
#
#
#
#
#
#
#  90%|████████▉ | 659/735 [1:39:37<10:24,  8.21s/it]
#
#
#
#
#
#
#  90%|████████▉ | 660/735 [1:39:51<12:19,  9.85s/it]
#
#
#
#
#
#
#  90%|████████▉ | 661/735 [1:40:01<12:20, 10.01s/it]
#
#
#
#
#
#
#  90%|█████████ | 662/735 [1:44:30<1:46:37, 87.63s/it]
#
#
#
#
#
#
#  90%|█████████ | 663/735 [1:44:31<1:13:50, 61.53s/it]
#
#
#
#
#
#
#  90%|█████████ | 664/735 [1:45:05<1:03:13, 53.43s/it]
#
#
#
#
#
#
#  90%|█████████ | 665/735 [1:45:14<46:38, 39.98s/it]
#
#
#
#
#
#
#  91%|█████████ | 666/735 [1:45:16<33:04, 28.77s/it]
#
#
#
#
#
#
#  91%|█████████ | 667/735 [1:45:17<22:54, 20.21s/it]
#
#
#
#
#
#
#  91%|█████████ | 668/735 [1:53:47<3:06:39, 167.15s/it]
#
#
#
#
#
#
#  91%|█████████ | 669/735 [1:59:08<3:54:46, 213.43s/it]
#
#
#
#
#
#
#  91%|█████████ | 670/735 [1:59:25<2:47:19, 154.45s/it]
#
#
#
#
#
#
#  91%|█████████▏| 671/735 [1:59:44<2:01:34, 113.98s/it]
#
#
#
#
#
#
#  91%|█████████▏| 672/735 [1:59:52<1:26:06, 82.01s/it]
#
#
#
#
#
#
#  92%|█████████▏| 673/735 [1:59:56<1:00:47, 58.83s/it]
#
#
#
#
#
#
#  92%|█████████▏| 674/735 [1:59:59<42:45, 42.06s/it]
#
#
#
#
#
#
#  92%|█████████▏| 675/735 [2:00:03<30:35, 30.59s/it]
#
#
#
#
#
#
#  92%|█████████▏| 676/735 [2:00:11<23:19, 23.72s/it]
#
#
#
#
#
#
#  92%|█████████▏| 677/735 [2:00:16<17:37, 18.23s/it]
#
#
#
#
#
#
#  92%|█████████▏| 678/735 [2:00:22<13:42, 14.43s/it]
#
#
#
#
#
#
#  92%|█████████▏| 679/735 [2:00:44<15:31, 16.64s/it]
#
#
#
#
#
#
#  93%|█████████▎| 680/735 [2:00:58<14:41, 16.02s/it]
#
#
#
#
#
#
#  93%|█████████▎| 681/735 [2:01:08<12:35, 14.00s/it]
#
#
#
#
#
#
#  93%|█████████▎| 682/735 [2:01:16<10:56, 12.38s/it]
#
#
#
#
#
#
#  93%|█████████▎| 683/735 [2:01:17<07:50,  9.06s/it]
#
#
#
#
#
#
#  93%|█████████▎| 684/735 [2:01:23<06:46,  7.96s/it]
#
#
#
#
#
#
#  93%|█████████▎| 685/735 [2:01:34<07:30,  9.01s/it]
#
#
#
#
#
#
#  93%|█████████▎| 686/735 [2:01:48<08:34, 10.50s/it]
#
#
#
#
#
#
#  93%|█████████▎| 687/735 [2:02:07<10:16, 12.84s/it]
#
#
#
#
#
#
#  94%|█████████▎| 688/735 [2:02:13<08:33, 10.93s/it]
#
#
#
#
#
#
#  94%|█████████▍| 690/735 [2:02:14<05:52,  7.83s/it]
#
#
#
#
#
#
#  94%|█████████▍| 691/735 [2:02:15<04:15,  5.80s/it]
#
#
#
#
#
#
#  94%|█████████▍| 692/735 [2:02:16<03:03,  4.26s/it]
#
#
#
#
#
#
#  94%|█████████▍| 693/735 [2:02:19<02:42,  3.87s/it]
#
#
#
#
#
#
#  94%|█████████▍| 694/735 [2:02:20<01:59,  2.92s/it]
#
#
#
#
#
#
#  95%|█████████▍| 695/735 [2:02:21<01:38,  2.47s/it]
#
#
#
#
#
#
#  95%|█████████▍| 696/735 [2:02:29<02:39,  4.08s/it]
#
#
#
#
#
#
#  95%|█████████▍| 697/735 [2:02:43<04:23,  6.94s/it]
#
#
#
#
#
#
#  95%|█████████▍| 698/735 [2:02:44<03:17,  5.34s/it]
#
#
#
#
#
#
#  95%|█████████▌| 699/735 [2:02:45<02:19,  3.87s/it]
#
#
#
#
#
#
#  95%|█████████▌| 700/735 [2:02:45<01:39,  2.85s/it]
#
#
#
#
#
#
#  95%|█████████▌| 701/735 [2:02:51<02:13,  3.92s/it]
#
#
#
#
#
#
#  96%|█████████▌| 702/735 [2:02:59<02:48,  5.11s/it]
#
#
#
#
#
#
#  96%|█████████▌| 703/735 [2:03:00<01:57,  3.67s/it]
#
#
#
#
#
#
#  96%|█████████▌| 704/735 [2:03:02<01:41,  3.28s/it]
#
#
#
#
#
#
#  96%|█████████▌| 705/735 [2:03:02<01:11,  2.38s/it]
#
#
#
#
#
#
#  96%|█████████▌| 706/735 [2:03:15<02:38,  5.48s/it]
#
#
#
#
#
#
#  96%|█████████▌| 707/735 [2:03:17<02:04,  4.46s/it]
#
#
#
#
#
#
#  96%|█████████▋| 709/735 [2:03:24<01:46,  4.11s/it]
#
#
#
#
#
#
#  97%|█████████▋| 710/735 [2:03:24<01:15,  3.01s/it]
#
#
#
#
#
#
#  97%|█████████▋| 712/735 [2:03:47<02:05,  5.48s/it]
#
#
#
#
#
#
#  97%|█████████▋| 713/735 [2:03:47<01:26,  3.95s/it]
#
#
#
#
#
#
#  97%|█████████▋| 714/735 [2:03:49<01:10,  3.34s/it]
#
#
#
#
#
#
#  97%|█████████▋| 715/735 [2:03:50<00:53,  2.69s/it]
#
#
#
#
#
#
#  98%|█████████▊| 718/735 [2:03:55<00:40,  2.39s/it]
#
#
#
#
#
#
#  98%|█████████▊| 719/735 [2:04:02<01:00,  3.76s/it]
#
#
#
#
#
#
#  98%|█████████▊| 720/735 [2:04:06<00:57,  3.87s/it]
#
#
#
#
#
#
#  98%|█████████▊| 721/735 [2:04:08<00:44,  3.15s/it]
#
#
#
#
#
#
#  98%|█████████▊| 722/735 [2:04:12<00:45,  3.53s/it]
#
#
#
#
#
#
#  98%|█████████▊| 723/735 [2:04:18<00:50,  4.20s/it]
#
#
#
#
#
#
#  99%|█████████▊| 724/735 [2:04:25<00:54,  4.96s/it]
#
#
#
#
#
#
#  99%|█████████▊| 725/735 [2:04:29<00:47,  4.72s/it]
#
#
#
#
#
#
#  99%|█████████▉| 727/735 [2:04:34<00:32,  4.12s/it]
#
#
#
#
#
#
#  99%|█████████▉| 729/735 [2:04:48<00:29,  4.93s/it]
#
#
#
#
#
#
#  99%|█████████▉| 730/735 [2:04:52<00:24,  4.85s/it]
#
#
#
#
#
#
#  99%|█████████▉| 731/735 [2:04:54<00:15,  3.89s/it]
#
#
#
#
#
#
# 100%|█████████▉| 732/735 [2:04:56<00:09,  3.24s/it]
#
#
#
#
#
#
# 100%|█████████▉| 733/735 [2:04:56<00:04,  2.36s/it]
#
#
#
#
#
#
# 100%|█████████▉| 734/735 [2:05:03<00:03,  3.81s/it]
#
#
#
#
#
#
# 100%|██████████| 735/735 [2:05:04<00:00,  2.82s/it]

# %%
# test serialization
t = nlp(data["Ocr text"][0])
import pickle
with open('test','wb') as f:
    pickle.dump(t, f)

with open('test', 'rb') as f:
    r = pickle.load(f)
type(r)

assert len(t) == len(r)
assert all([str(r[i]) == str(t[i]) for i in range(len(r))])
# Out:
# True

# %%
# serialize
# note: each file is about 1Gb on disk
import os
from tqdm import tqdm_notebook
import pickle
if not os.path.exists('spacy_objs'):
    os.mkdir('spacy_objs')
for i,obj in tqdm(enumerate(parsed), total=735):
    with open(os.path.join('spacy_objs', 'doc-{:04}.spacy'.format(i)), 'wb') as f:
        pickle.dump(obj, f)

# %%
# deserialize
import os
parsed = []
for file in sorted(os.listdir('spacy_objs')):
    if file.endswith('.spacy'):
        with open(os.path.join('spacy_objs',file), 'rb') as f:
            parsed.append(pickle.load(f))
print(len(parsed))

# %%
# create text blob for whole-corpus analysis
blob = '\n<DOC_DELIM>\n\n'.join(data['Ocr text'].map(str).tolist())

# %%
with open('all_ocr.txt','wb') as f:
    f.write(bytes(blob, 'UTF-8'))

# %%
print(len(blob))
total = nlp(blob[:int(1e6)])
# longer than 1e6 characters, which is default upper limit for spacy.
# if not using parser or NER engines, which require 1GB memory per 1e5 characters, probably ok
# Out:
# 51985375

# %% [markdown]
# ideas:
# Should separate words appearing in camel case as easy fix for missed spaces
# otherwise... difficult, vocab based methods?

# %% [raw]
# get names from:
#
# https://www.behindthename.com/names/1 to 75
#
# use as search terms for people
#
# potential address regexes:
# https://stackoverflow.com/questions/11456670/regular-expression-for-address-field-validation
#
# \d{1,5}\s\w.\s(\b\w*\b\s){1,2}\w*\.
#
#
#        .Append("(?<h>^[\d]+[ ])(?<s>.+$)|")                'find the 2013 1st ambonstreet
#        .Append("(?<s>^.*?)(?<h>[ ][\d]+[ ])(?<e>[\D]+$)|") 'find the 1-7-4 Dual Ampstreet 130 A
#        .Append("(?<s>^[\D]+[ ])(?<h>[\d]+)(?<e>.*?$)|")    'find the Terheydenlaan 320 B3
#        .Append("(?<s>^.*?)(?<h>\d*?$)")
#
#     \d+[ ](?:[A-Za-z0-9.-]+[ ]?)+(?:Avenue|Lane|Road|Boulevard|Drive|Street|Ave|Dr|Rd|Blvd|Ln|St)\.?
#
#     \s*([0-9]*)\s((NW|SW|SE|NE|S|N|E|W))?(.*)((NW|SW|SE|NE|S|N|E|W))?((#|APT|BSMT|BLDG|DEPT|FL|FRNT|HNGR|KEY|LBBY|LOT|LOWR|OFC|PH|PIER|REAR|RM|SIDE|SLIP|SPC|STOP|STE|TRLR|UNIT|UPPR|\,)[^,]*)(\,)([\s\w]*)\n
#
#     /\s+(\d{2,5}\s+)(?![a|p]m\b)(([a-zA-Z|\s+]{1,5}){1,2})?([\s|\,|.]+)?(([a-zA-Z|\s+]{1,30}){1,4})(court|ct|street|st|drive|dr|lane|ln|road|rd|blvd)([\s|\,|.|\;]+)?(([a-zA-Z|\s+]{1,30}){1,2})([\s|\,|.]+)?\b(AK|AL|AR|AZ|CA|CO|CT|DC|DE|FL|GA|GU|HI|IA|ID|IL|IN|KS|KY|LA|MA|MD|ME|MI|MN|MO|MS|MT|NC|ND|NE|NH|NJ|NM|NV|NY|OH|OK|OR|PA|RI|SC|SD|TN|TX|UT|VA|VI|VT|WA|WI|WV|WY)([\s|\,|.]+)?(\s+\d{5})?([\s|\,|.]+)/i
#
#
#     /\b(\d{2,5}\s+)(?![a|p]m\b)(NW|NE|SW|SE|north|south|west|east|n|e|s|w)?([\s|\,|.]+)?(([a-zA-Z|\s+]{1,30}){1,4})(court|ct|street|st|drive|dr|lane|ln|road|rd|blvd)/i
#
# https://smartystreets.com/products/single-address?mode=extract
# Paid option, or 250 address free address verifications per month. Address extraction/verification tool
#
# Yelp and Google API for addresses?
#
#
# http://regexlib.com/Search.aspx?k=street&AspxAutoDetectCookieSupport=1
#
#
# \d{1,3}.?\d{0,3}\s[a-zA-Z]{2,30}\s[a-zA-Z]{2,15}
#
# ^\d{5}(-\d{4})?$  # zip codes
#
# ^(?n:(?<address1>(\d{1,5}(\ 1\/[234])?(\x20[A-Z]([a-z])+)+ )|(P\.O\.\ Box\ \d{1,5}))\s{1,2}(?i:(?<address2>(((APT|B LDG|DEPT|FL|HNGR|LOT|PIER|RM|S(LIP|PC|T(E|OP))|TRLR|UNIT)\x20\w{1,5})|(BSMT|FRNT|LBBY|LOWR|OFC|PH|REAR|SIDE|UPPR)\.?)\s{1,2})?)(?<city>[A-Z]([a-z])+(\.?)(\x20[A-Z]([a-z])+){0,2})\, \x20(?<state>A[LKSZRAP]|C[AOT]|D[EC]|F[LM]|G[AU]|HI|I[ADL N]|K[SY]|LA|M[ADEHINOPST]|N[CDEHJMVY]|O[HKR]|P[ARW]|RI|S[CD] |T[NX]|UT|V[AIT]|W[AIVY])\x20(?<zipcode>(?!0{5})\d{5}(-\d {4})?))$
#
# ^\s*((?:(?:\d+(?:\x20+\w+\.?)+(?:(?:\x20+STREET|ST|DRIVE|DR|AVENUE|AVE|ROAD|RD|LOOP|COURT|CT|CIRCLE|LANE|LN|BOULEVARD|BLVD)\.?)?)|(?:(?:P\.\x20?O\.|P\x20?O)\x20*Box\x20+\d+)|(?:General\x20+Delivery)|(?:C[\\\/]O\x20+(?:\w+\x20*)+))\,?\x20*(?:(?:(?:APT|BLDG|DEPT|FL|HNGR|LOT|PIER|RM|S(?:LIP|PC|T(?:E|OP))|TRLR|UNIT|\x23)\.?\x20*(?:[a-zA-Z0-9\-]+))|(?:BSMT|FRNT|LBBY|LOWR|OFC|PH|REAR|SIDE|UPPR))?)\,?\s+((?:(?:\d+(?:\x20+\w+\.?)+(?:(?:\x20+STREET|ST|DRIVE|DR|AVENUE|AVE|ROAD|RD|LOOP|COURT|CT|CIRCLE|LANE|LN|BOULEVARD|BLVD)\.?)?)|(?:(?:P\.\x20?O\.|P\x20?O)\x20*Box\x20+\d+)|(?:General\x20+Delivery)|(?:C[\\\/]O\x20+(?:\w+\x20*)+))\,?\x20*(?:(?:(?:APT|BLDG|DEPT|FL|HNGR|LOT|PIER|RM|S(?:LIP|PC|T(?:E|OP))|TRLR|UNIT|\x23)\.?\x20*(?:[a-zA-Z0-9\-]+))|(?:BSMT|FRNT|LBBY|LOWR|OFC|PH|REAR|SIDE|UPPR))?)?\,?\s+((?:[A-Za-z]+\x20*)+)\,\s+(A[LKSZRAP]|C[AOT]|D[EC]|F[LM]|G[AU]|HI|I[ADLN]|K[SY]|LA|M[ADEHINOPST]|N[CDEHJMVY]|O[HKR]|P[ARW]|RI|S[CD]|T[NX]|UT|V[AIT]|W[AIVY])\s+(\d+(?:-\d+)?)\s*$
#
# ^[ \w]{3,}([A-Za-z]\.)?([ \w]*\#\d+)?(\r\n| )[ \w]{3,},\x20[A-Za-z]{2}\x20\d{5}(-\d{4})?$
#
#
# ((?<strPOBox>((POBox|PO\sBox)\s*\d*)),?\s?)?(((?<strUnit>([\w\d\s\,]*)),\s?)?( (?<strStreet>([\w\s\-]*\w\s(st\s)?[\w]*\s(street|st|road|rd|close|cl|avenue|ave|av|path|ph|drive|drv|LOOP|COURT|CT|CIRCLE|LANE|LN)) ),?\s?))?((?<strTown>([\p{Ll}\p{Lu}\p{Lo}\p{Pc}\p{Lt}\p{Lm}\s]*)),?\s?)?((?<strState>(Victoria|VIC|New South Wales|NSW|South Australia|SA|Northern Territory|NT|West Australia|WA|Tasmania|TAS|ACT|Queensland|QLD))\s*)?(?<strPostalCode>(\d{4}),?\s?)?(?<strCountry>(Australia))?
#
#     ((\d{1,6}\-\d{1,6})|(\d{1,6}\\\d{1,6})|(\d{1,6})(\/)(\d{1,6})|(\w{1}\-?\d{1,6})|(\w{1}\s\d{1,6})|((P\.?O\.?\s)((BOX)|(Box))(\s\d{1,6}))|((([R]{2})|([H][C]))(\s\d{1,6}\s)((BOX)|(Box))(\s\d{1,6}))?)$  # street number
#
#     ^(\d{3,})\s?(\w{0,5})\s([a-zA-Z]{2,30})\s([a-zA-Z]{2,15})\.?\s?(\w{0,5})$
#
#     ^\d{1,6}\040([A-Z]{1}[a-z]{1,}\040[A-Z]{1}[a-z]{1,})$|^\d{1,6}\040([A-Z]{1}[a-z]{1,}\040[A-Z]{1}[a-z]{1,}\040[A-Z]{1}[a-z]{1,})$|^\d{1,6}\040([A-Z]{1}[a-z]{1,}\040[A-Z]{1}[a-z]{1,}\040[A-Z]{1}[a-z]{1,}\040[A-Z]{1}[a-z]{1,})$
#
#     ^ (?<FullStreet> (?<Detail>(?:C/[-O]?[a-z\ ]*?)?\ *)? (?<POBox>P[\.\ ]?O[\.\ ]?\ ?Box\ *\d+) | (?:(?<Detail>(?:C/[-O]?)?[\w\ ,\.']+?),?/?\ *?)? \ *?\b(?<StreetNum>(?:\d+-)?\d+[a-z]?)[\ ] (?<StreetFullName> (?<StreetName>(?:[\w\ '-]|st)+) (?:\b(?<StreetType>ALLEY|ALLY|APPROACH|APP|ARCADE|ARC|AVENUE|AVE|BOULEVARD|BLVD|BROW|BYPASS|BYPA|CAUSEWAY|CWAY|CIRCUIT|CCT|CIRCUS|CIRC|CLOSE|CL|COPSE|CPSE|CORNER|CNR|COVE|COURT|CRT|CT|CRESCENT|CRES|DRIVE|DR|END|ESPLANANDE|ESP|FLAT|FREEWAY|FWAY|FRONTAGE|FRNT|GARDENS|GDNS|GLADE|GLD|GLEN|GREEN|GRN|GROVE|GR|HEIGHTS|HTS|HIGHWAY|HWY|LANE|LINK|LOOP|MALL|MEWS|PACKET|PCKT|PARADE|PDE|PARK|PARKWAY|PKWY|PLACE|PL|PROMENADE|PROM|RESERVE|RES|RIDGE|RDGE|RISE|ROAD|RD|ROW|SQUARE|SQ|STREET|ST|STRIP|STRP|TARN|TERRACE|TCE|THOROUGHFARE|TFRE|TRACK|TRAC|TRUNKWAY|TWAY|VIEW|VISTA|VSTA|WALK|WAY|WALKWAY|WWAY|YARD )\b) ) ) (?:,?\ *?(?<Town>[a-z'.]+(?:,?\ +[a-z'.]+)*?))? (?:,?\ *?(?<State>Victoria|VIC|New South Wales|NSW|South Australia|SA|Northern Territory|NT|West Australia|WA|Tasmania|TAS|Australian Capital Territory|ACT|Queensland|QLD))? (?:,?\ *?(?<PostalCode>\d{3,4}))? (?:,?\ *?(?<Country>Au(?:stralia)?))? (?:(?=[^$])\s)* $
#
#
#  the below contains (?>) groups, non backtracking. These do not exist in Python RegEx
#     /(?:(?<=^)|(?<=[;:.,|][ ])|(?<=[[('"]))(?:[)]?P\.?O\.?(?:(?i)[ ]?Box)?[ ]{0,2}(?<PO>\d{1,5})[)]?|(?<HouseNumber>(?>(?:(?<NumberException>(?:19[789]|20[0123])\d)|\d+?(?:[-\\\/]\d{1,3})?)(?=(?:[;,]|[-\\\/]?[A-Za-z]\d?)?\s)))(?:(?<DoorSide>[-\\\/]?[A-Za-z]\d{0,2}))?,?\s{0,2}(?>(?:(?:^|[ ]{1,2})(?<StreetPrefix>AU|EI?|GR|H[AW]|JO|K|M[AEM]|N[EOW]?|O[HLMV]|RD|S[EW]?|TE|W)\b)?)(?:(?:^|[ ]{1,2})(?<StreetName>(?:\p{Lu}[-'\p{L}]*?(?:\.?[ ]{1,2}\p{Lu}[-'\p{L}]*?){0,8}?(?>(?<StreetNameIndicator>(?i)BOULEVARD|PLAZA|ROAD|STR(?:ASSE|EET)|WA(?:LK|Y))?)|(?<StreetOrdinal>\d{1,3}(?:[. ]?(?:°|st|[nr]d|th))))\b))(?:(?:(?>[ ]{1,2}(?i)(?<StreetType>A(?:C(?:CESS|RES)|LLEY|NX|PPROACH|R(?:CADE|TERY)|VE(?:NUE)?)|B(?:A(?:NK|SIN|Y)|CH|E(?:ACH|ND)|L(?:DG|VD)?|O(?:ULEVARD|ARDWALK|WL)|R(?:ACE|AE|EAK|IDGE|O(?:ADWAY|OK|W))?|YPASS)|C(?:A(?:NAL|USEWAY)|ENTRE(?:WAY)?|H(?:A(?:NN?EL|SE)?)?|I(?:R(?:C(?:LET?|U(?:IT|S)))?)?|L(?:B|OSE)?|O(?:MMON|NCOURSE|OP|PSE|R(?:[DK]|NER|S[OT])|UR(?:[VS]E|T(?:YARD)?)|VE)?|R(?:ES(?:CENT|T)?|IEF|OSS(?:ING)?)|T[RS]?|U(?:LDESAC|RVE)|V)|D(?:ALE|EVIATION|I[PV]|M|OWNS|R(?:IVE(?:WAY)?)?)|E(?:ASEMENT|DGE|LBOW|N(?:D|TRANCE)|S(?:PLANADE|T(?:ATE|S))|X(?:P(?:(?:(?:RESS)?WA)?Y)|T(?:ENSION)?))|F(?:AIRWAY|I(?:ELDS?|RETRAIL)|L(?:DS?|S)|O(?:LLOW|R(?:D|MATION))|R(?:D|EEWAY|ONT(?:AGE|ROAD)?))|G(?:A(?:P|RDENS?|TE(?:S|WAY)?)|L(?:ADE|EN)|R(?:ANGE|EEN|O(?:UND|V(?:ET?)?))?)|H(?:AVEN|BR|E(?:ATH|IGHTS)|I(?:GHWAY|LL)|L|OUSE|TS|UB|WY)|I(?:NTER(?:CHANGE)?|SLAND)|J(?:C|UNCTION)|K(?:EY|NOLL)|L(?:A(?:NE(?:WAY)?)?|DG|IN(?:E|K)|N|O(?:O(?:KOUT|P)|WER)?)|M(?:A(?:LL)?|DWS?|E(?:A(?:D|NDER)|WS)|L|NR|OT(?:EL|ORWAY))|NO(?:OK)?|O(?:L|UTLOOK|V(?:ERPASS)?)|P(?:A(?:R(?:ADE|K(?:LANDS|WAY)?)|SS|TH(?:WAY)?)?|DE|I(?:ER|[KN]E)|KW?Y|L(?:A(?:CE|ZA)|Z)?|O(?:CKET|INT|RT)|RO(?:MENADE|PERTY)|T|URSUIT)?|QUA(?:D(?:RANT)?|YS?)|R(?:A?(?:MBLE|NCH)|DG?|E(?:ACH|S(?:ERVE|T)|T(?:REAT|URN))|I(?:D(?:E|GE)|NG|S(?:E|ING))|O(?:AD(?:WAY)?|TARY|U(?:ND|TE)|W)|R|UN)|S(?:CH|(?:ER(?:VICE)?WAY)|IDING|LOPE|MT|P(?:PGS|UR)|Q(?:UARE)?|T(?:A(?:TE)?|CT|EPS|HY|PL|RAND|R(?:EET|IP)|TER)?|UBWAY)|T(?:ARN|CE|E(?:R(?:RACE)?)?|HRO(?:UGHWAY|WAY)|O(?:LLWAY|P|R)|R(?:A(?:CK|IL)|FY|L)?|URN)|UN(?:DERPASS|IV)?|V(?:AL(?:E|LEY)|I(?:EW|S(?:TA)?)?|L(?:GS?|Y))|W(?:A(?:L[KL](?:WAY)?|Y)|HARF|YND)|XING)\b\.?){1,2})??(?>(?:[ ]{1,2}(?<StreetSuffix>E|N[EW]?|S[EW]?|W)\b)?))(?:(?:^|[ ]{1,2}|[;,.]\s{0,2}?)(?i)(?<Apt>(?:[#]?\d{1,5}(?:[. ]{0,2}(?:°|st|[nr]d|th))?[;,. ]{0,2})?(?:(?:(?>(?:A|DE)P(?:AR)?T(?:MENT)?S?|B(?:UI)?LD(?:IN)?G?|FL(?:(?:OO)?R)?|HA?NGS?R|LOT|PIER|RM|S(LIP|PC|T(E|OP))|TRLR|UNIT|(?=[#]))(?:[ ]{1,2}[#]?\w{1,5})??|BA?SE?ME?N?T|FRO?NT|LO?BBY|LOWE?R|OF(?:C|FICE)|P\.?H|REAR|SIDE|UPPR)){1,3}(?:[#;,. ]{1,3}(?:[-.]?[A-Z\d]){1,3})?)[;,.]?)?)(?<CityState>[-;,.[(]?\s{1,4}(?<City>[A-Z][A-Za-z]{1,16}[.]?(?:[- ](?:[A-Z][A-Za-z]{0,16}|[a-z]{1,3})(?:(?:[- ][A-Za-z]{1,17}){1,7})?)?)(?<!\s[ACDF-IK-PR-W][AC-EHI-PR-Z])[)]?(?>(?<State>[-;,.]?\s{1,4}[[(]?(?<StateAbbr>A[LKSZRAP]|C[AOT]|D[EC]|F[LM]|G[AU]|HI|I[ADLN]|K[SY]|LA|M[ADEHINOPST]|N[CDEHJMVY]|O[HKR]|P[ARW]|RI|S[CD]|T[NX]|UT|V[AIT]|W[AIVY])\b[])]?|[-;,.]\s{0,3}[ ][[(]?(?=[A-Z])(?<StateName>(?i)Ala(?:bam+a|[sz]ka)|Ari[sz]ona|Arkan[sz]as|California|Colorado|Con+ec?t+icut+|Delaw[ae]re?|Flori?da|Georgia|Haw+ai+|Idaho|Ill?inois|Indiana|Iowa|Kansas|Kentu[ck]+[iy]|Louis+ian+a|Ma(?:ine|r[iy]land|s+achuset+s)|Mi(?:chigan|n+es+ot+a|s+is+ip+i|s+ouri)|Montana|Ne(?:bra[sz]ka|vada|w[ ]?(?:Hamp?shire|Jerse[iy]|Mexico|York))|[NS](?:o[ru]th|[.])[ ]?(?:Carolina|Dakota)|Ohio|Oklahoma|Oregon|Pen+s[iy]lvan+[iy]a|Rh?oa?de?[ ]?Island|Ten+es+e+|Texas|Ut+ah?|Vermont|Washington|(?:W(?:est|[.])?[ ]?)?Virginia|Wi[sz]cou?nsin|W[iy]om[iy]+ng?)[])]?)?)(?(State)|(?:(?<=[)])|(?! [A-Z]))))?(?>(?:[-;,.\s]{0,4}(?:^|[ ]{1,2})[[(]?(?<ZipCode>(?!0{5})\d{5}(?:-\d{4})?)[])]?)?)(?(State)|(?(ZipCode)|(?(City)(?!)|(?(PO)|(?(NumberException)(?!)|(?(StreetNameIndicator)|(?(StreetType)|(?(StreetPrefix)|(?!)))))))))(?=[]).?!'"\s]|$)(?![ ]+\d)/gmx
#
#     ^(?<address1>(?>\d{1,6}(?>\ 1\/[234])?( (N(orth)?|S(outh)?)? ?(E(ast)?|W(est)?))?((?> \d+ ?(th|rd|st|nd))|(?> [A-Z](?>[a-z])+)+) (?>(?i)THROUGHWAY|TRAFFICWAY|CROSSROADS|EXPRESSWAY|BOULEVARD|CROSSROAD|EXTENSION|JUNCTIONS|MOUNTAINS|STRAVENUE|UNDERPASS|CAUSEWAY|CRESCENT|CROSSING|JUNCTION|MOTORWAY|MOUNTAIN|OVERPASS|PARKWAYS|TURNPIKE|VILLIAGE|VILLAGES|CENTERS|CIRCLES|COMMONS|CORNERS|ESTATES|EXPRESS|FORESTS|FREEWAY|GARDENS|GATEWAY|HARBORS|HIGHWAY|HOLLOWS|ISLANDS|JUNCTON|LANDING|MEADOWS|MOUNTIN|ORCHARD|PARKWAY|PASSAGE|PRAIRIE|RANCHES|SPRINGS|SQUARES|STATION|STRAVEN|STRVNUE|STREETS|TERRACE|TRAILER|TUNNELS|VALLEYS|VIADUCT|VILLAGE|ALLEE|ARCADE|AVENUE|BLUFFS|BOTTOM|BRANCH|BRIDGE|BROOKS|BYPASS|CANYON|CAUSWA|CENTER|CENTRE|CIRCLE|CLIFFS|COMMON|CORNER|COURSE|COURTS|CRSENT|CRSSNG|DIVIDE|DRIVES|ESTATE|EXTNSN|FIELDS|FOREST|FORGES|FREEWY|GARDEN|GATEWY|GATWAY|GREENS|GROVES|HARBOR|HIGHWY|HOLLOW|ISLAND|ISLNDS|JCTION|JUNCTN|KNOLLS|LIGHTS|MANORS|MEADOW|MEDOWS|MNTAIN|ORCHRD|PARKWY|PLAINS|POINTS|RADIAL|RADIEL|RAPIDS|RIDGES|SHOALS|SHOARS|SHORES|SKYWAY|SPRING|SPRNGS|SQUARE|STRAVN|STREAM|STREME|STREET|SUMITT|SUMMIT|TRACES|TRACKS|TRAILS|TUNNEL|TURNPK|UNIONS|VALLEY|VIADCT|VILLAG|ALLEE|ALLEY|ANNEX|AVENU|AVNUE|BAYOO|BAYOU|BEACH|BLUFF|BOTTM|BOULV|BRNCH|BRDGE|BROOK|BURGS|BYPAS|CANYN|CENTR|CNTER|CIRCL|CRCLE|CLIFF|COURT|COVES|CREEK|CRSNT|CREST|CURVE|DRIVE|FALLS|FERRY|FIELD|FLATS|FORDS|FORGE|FORKS|FRWAY|GARDN|GRDEN|GRDNS|GTWAY|GLENS|GREEN|GROVE|HARBR|HRBOR|HAVEN|HIWAY|HILLS|HOLWS|ISLND|ISLES|JCTNS|KNOLL|LAKES|LNDNG|LIGHT|LOCKS|LODGE|LOOPS|MANOR|MILLS|MISSN|MOUNT|MNTNS|PARKS|PKWAY|PKWYS|PATHS|PIKES|PINES|PLAIN|PLAZA|POINT|PORTS|RANCH|RNCHS|RAPID|RIDGE|RIVER|ROADS|ROUTE|SHOAL|SHOAR|SHORE|SPRNG|SPNGS|SPURS|STATN|STRAV|STRVN|SUMIT|TRACE|TRACK|TRAIL|TRLRS|TUNEL|TUNLS|TUNNL|TRNPK|UNION|VALLY|VIEWS|VILLG|VILLE|VISTA|WALKS|WELLS|ALLY|ANEX|ANNX|AVEN|BEND|BLUF|BLVD|BOUL|BURG|BYPA|BYPS|CAMP|CNYN|CAPE|CSWY|CENT|CNTR|CIRC|CRCL|CLFS|CLUB|CORS|CRSE|COVE|CRES|XING|DALE|DRIV|ESTS|EXPR|EXPW|EXPY|EXTN|EXTS|FALL|FRRY|FLDS|FLAT|FLTS|FORD|FRST|FORG|FORK|FRKS|FORT|FRWY|GRDN|GDNS|GTWY|GLEN|GROV|HARB|HIWY|HWAY|HILL|HLLW|HOLW|INLT|ISLE|JCTN|JCTS|KEYS|KNOL|KNLS|LAKE|LAND|LNDG|LANE|LOAF|LOCK|LCKS|LDGE|LODG|LOOP|MALL|MNRS|MDWS|MEWS|MILL|MSSN|MNTN|MTIN|NECK|ORCH|OVAL|PARK|PKWY|PASS|PATH|PIKE|PINE|PNES|PLNS|PLZA|PORT|PRTS|RADL|RAMP|RNCH|RPDS|REST|RDGE|RDGS|RIVR|ROAD|SHLS|SHRS|SPNG|SPGS|SPUR|SQRE|SQRS|STRA|STRM|STRT|TERR|TRCE|TRAK|TRKS|TRLS|TRLR|TUNL|VLLY|VLYS|VDCT|VIEW|VILL|VLGS|VIST|VSTA|WALK|WALL|WAYS|WELL|ALY|ANX|ARC|AVE|AVN|BCH|BND|BLF|BOT|BTM|BRG|BRK|BYP|CMP|CPE|CEN|CTR|CIR|CLF|CLB|COR|CTS|CRK|DAM|DIV|DVD|DRV|EST|EXP|EXT|FLS|FRY|FLD|FLT|FRD|FRG|FRK|FRT|FWY|GLN|GRN|GRV|HBR|HVN|HTS|HWY|HLS|ISS|JCT|KEY|KYS|KNL|LKS|LGT|LCK|LDG|MNR|MDW|MNT|MTN|NCK|OVL|PRK|PKY|PLN|PLZ|PTS|PRT|PRR|RAD|RPD|RST|RDG|RIV|RVR|RDS|ROW|RUE|RUN|SHL|SHR|SPG|SQR|SQU|STA|STN|STR|SMT|TER|TRK|TRL|VLY|VIA|VWS|VLG|VIS|VST|WAY|WLS|AV|BR|CP|CT|CV|DL|DM|DV|DR|FT|HT|HL|IS|KY|LK|LN|LF|MT|PL|PT|PR|RD|SQ|ST|UN|VW|VL|WY))( (N(orth)?|S(outh)?)? ?(E(ast)?|W(est)?)?)?)$

# %%
import re
address_regex = re.compile('''\s+(\d{2,5}\s+)(?![a|p]m\b)(([a-zA-Z|\s+]{1,5}){1,2})?([\s|\,|.]+)?(([a-zA-Z|\s+]{1,30}){1,4})(court|ct|street|st|drive|dr|lane|ln|road|rd|blvd)([\s|\,|.|\;]+)?(([a-zA-Z|\s+]{1,30}){1,2})([\s|\,|.]+)?\b(AK|AL|AR|AZ|CA|CO|CT|DC|DE|FL|GA|GU|HI|IA|ID|IL|IN|KS|KY|LA|MA|MD|ME|MI|MN|MO|MS|MT|NC|ND|NE|NH|NJ|NM|NV|NY|OH|OK|OR|PA|RI|SC|SD|TN|TX|UT|VA|VI|VT|WA|WI|WV|WY)([\s|\,|.]+)?(\s+\d{5})?([\s|\,|.]+)''', 
                           re.IGNORECASE)

address_regex = re.compile(r'\d',
                          re.IGNORECASE)

address_regex.findall(data.loc[3, "Ocr text"])
# Out:
# []

# %%
data.loc[3, "Ocr text"]

# %%
test = ['']*4
test[0] = '''as a role model to others. The medium of expression includes 
but is not limited to written, vocal, dance, visual, or instrumental. All 
nominations must include a sample of the expressed medium, in completed 
form (audio, video, print). pgNbr=32 ""Women Making History"" Awards San 
Francisco Commission on the Status of Women 25 Van Ness Avenue, Room 
130 San Francisco, CA 94102 ""Women Making History"" Awards Nomination 
Form Nomination Category (Please Check-One): The Arts Women's Health Young 
Women's Empowerment This is your opportunity to honor a woman or an 
organization that is making an innovative contribution to women's 
history in San Francisco. Awards will be 
presented in the above th'''.replace('\n','')

test[1] = '''am interested in hearing more about the Women Make Change 
Training: Name Address/Zip Phone (day) (eve) Age Organization/Group 
(if any) Call Sonja at (415) 291-5454 if you would like: • more 
information • to be involved in organizing the Women Make Change 
Training (we need your input!) • child care or transportation costs 
paid for Women's AIDS 
Network. 3543 18tb Street, Suite 11. San Francisco, CA 94110. pgNbr=27 
12/16/96 16:10 12-16-1996 4.: 11PM FROM ^ j^i_o-xo-yo i-n-<ii 1^.11 t-i'i 
yMi.ut.N-»MUUsis.>«>y J & 41S5541475 P.03_ .AO \f\.0 C7 12/ 13/96 To ; 
WAN Board Fr; I^isa O'Connor Re:Proposal for fullfilling my $500.00 
Agreement for 1996 As the year comes ro an end, I'd like to propose 
the following way to finish my financial commitment as board member; 
TO date, I have contributed; CO - $150,00 Macys Passport $ 75.00 to 
be paid by check ny 2/97 $225.00 (following) proposed funds $500.00 I 
would like to propose that All the projected time, energy, 
set up/pick-u'''.replace('\n','')

test[2] = '''epidemic. However, studies have shown that the rates of 
those being tested drop significantly if the results are not fully 
anonymous. With the knowledge that their results would be reported 
to state health departments and the federal government, N fewer people 
will seek HIV counseling and testing services. This would not only 
result in people being unable to access the appropriate care for 
treatment that Representative Coburn expresses much interest in — 
because 3543 18TH STREET SUITE 11 they would not know their HIV status — 
but would also present an SAN FRANCISCO inaccurate piaure of the 
epidemic's demographics. CA 94110 415.621.4160 TEL 415.575.1181 
FAX pgNbr=19 ALRP/WAN — HJi. 3937 — two Partner Notification 
Representative Coburn also fails to recognize the serious repercussions 
that would be created by partner notification, thereby precluding 
its efficacy. Women are at an extremely high risk of being subjected 
to violence following disclosure of their HIV status to a partner. 
Knowing that forced partner notification has been instituted would 
discourage women, in particular, from '''.replace('\n','')

test[3]  = '''
luable program. We are pleased to have your support and assure you of 
our best efforts and best wishes, too. Cordially,// / "" Ann Grogan 
for CUOyt;^ • lo ^ r>nQjuULAiU5ta^ y(V^^-CL<;^ cx^ , UOjl. SLD VD ^^
\-4^yJZjQQ_j Q^aaunoflijb-ffvvci -!W£) \o^ -W-ea>c^A_jM2ru^ pgNbr=103 
tworlc MACY'S PASSPORTS Saturday, September 21,1996 Located at Union 
Square, San Francisco Tickets are $10, all proceeds of our tickets go 
to directly to WAN Each ticket turned in the day of the event will add 
an additional $3 Board members will be selling Passport tickets 
beginning in July For more info call Alyssa at 621-4160 pgNbr=104 WAN 
BOARD 1996 1) Margot Antonetty *Project Director, Integrated Services 
Network 2227 15th St. Baker Places, Inc. S.F., CA 94114 310 Townsend, 
#300 w 546-9946 S.F., CA 94107 h 255-1984 f 546-9947 Personnel, 
Fundraising/Finance 2) Hazel Betsey, SECRETARY 191 Duboce St., #101 S.F., 
CA 94103 w 487-4743 Mon. a.m., 9-1 p.m. w (510) 658-6930 Fri. a.m., 
10-2 p.m. h 864-4996 Personnel, Fundraising/Finance Public Benefits 
Counselor 3) Laura Carcagno AIDS Benefit Counselors *656 Key Route Blvd. 
470 Castro St., Ste. 202 Albany, CA 94706 w 703-9940 S.F.,CA 94114 h 
(510)528-7168 f 703-9942 *PubIic 4) Hleen Hansen Policy Director AIDS 
238-A Castro St. Legal Referral Panel (ALRP) 114 Sansome St., Ste. 
1129 S.F., CA 94114 w 291-5472 S.F., CA 94104 h 621-5620 Public f 291-5833 
Policy Director Women's 
AIDS Network 114 Sansome St., Ste. 1129 S.F., CA 94104 5) 
Anna Heath 1060 Bush St., #207 S.F., CA 94109 h 771-4041 6) 
Helen Miramontes *Associate Clinical 
Professor 481 Pointe Pacific Dr., #8 UCSF, School of Nursing 
Daly City, CA 94104 Box 0608 w 476-6602 S.F., CA 94143-0608 h 
994-8664 f 476-6042 7) Lisa O'Connor, PRESIDENT Senior Counselor 
*P0 Box 427298 HIV Services S.F., CA 94142 Walden House, Inc. 
w 241-5555 890 Hayes Street h (510)834-6023 S.F.,CA 94901 f 241-5569 
p 338-8891 Personnel COMMITTEE PARTICIPATION BOLDED & * INDICATES 
PREFERRED MAIUNG ADDRESS pgNbr=105 *CIinical Supervisor 8) Lorene 
Romero, VICE-PRESIDENT Baker Places 9596 Orion Dr. Support & Permanent 
Housing 545 Mission St., 5th Floor Windsor, CA 95492 w 284-1740x35 S.F., 
CA 94105 h (707)838-3292 f 284-1750 Chair, Personnel Fundraising/Pinance 
Educator and Outreach Worker 9) Naomi Schegloff TB Outreach Prevention 
Services (TOPS) *1473 Waller St. Dept. of Public Health S.F.,CA94117 
973 Market w Street, Ste. 205 597-7950x12 h 681-4152 S.F., CA 94103 f 
974-5791 Chair, Fundraising/Pinance Asst. to Director of Community 
Building 10) Lateefah Simon The Center of *785 Fulton Young Women's 
Development St., #A Street Survival Project S.F., CA 94102 1095 
Market w 487-8662 St., Ste. 608 h 626-1135 S.F., CA 94102 f 487-8664 
Fundraising/Finance p 709-5132 Housing Project Developer 11) Ruthy 
Talansky, TREASURER Bernal 3525 17th Heights Housing Corporation St., 
#9 515 Cortland Ave. S.F.,CA 94110 w 206-2147 S.F.,CA 94110 h 621-6364 
f 648-0793 *WAN Administrator Alyssa Izen, Staff Women's AIDS Network 
3756 20th St., # 2 584 Castro St., Ste. 321 S.F.,CA 94110 w 621-4160 
S.F., CA 94114 h 285-4605 f 863-4740 WAN Erma Administrator, Special 
Women's Fund Smith, Ex-Officio Health Services Board Member Coordinator, 
CARE Clinic Planned Parenthood Golden Gate w 202-7430 815 h 641-1275 
Eddy St., Ste. 100 f 776-1449 S.F., CA 94104 COMMITTEE PARTICIPATION 
BOLDED & * INDICATES PREFERRED MAIUNG ADDRESS pgNbr=106 Lcrene S- 
Romero TT ^ (707)838-4629 3t7/6/96 : 2 02 AM j 4/6 Hours All full time 
employees are expected to work an average 40 hour week. Part- time employees 
must work a minimum of twenty hours to be eligible tor benefits listed herein. 
The number of hours and days per week are flexible but need to be approved by 
the supervisor or Board President. Hours worked must be approved by the 
supervisor or Board President. I Sick Ledve 
When empl'''.replace('\n','')

import datetime
now = datetime.datetime.now()
print(now)
print([address_regex.findall(i) for i in test])
print('elapsed: {}'.format(datetime.datetime.now() - now))
# Out:
# 2019-06-28 19:24:39.084803
# [[], [], [], []]
# elapsed: 0:00:00.833785

# %% [markdown]
# Docs with...
#
# Names:
# sfaf dinner
# usmss95-04-001-069
#
# Addresses:
# mss95-04_001_071 pamphlet
# mss95-04-001-047 support groups page
# glbths_200046-001-010-redacted (client comments form, p128)
